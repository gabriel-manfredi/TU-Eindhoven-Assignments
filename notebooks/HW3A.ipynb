# %%
import numpy as np
import pandas as pd
import os
import random
import math
import matplotlib.pyplot as plt

# %%
class MLP:

    def __init__(self, batch_size, alpha, epochs, no_neurons, use_sigmoid: bool):
        self.batch_size = batch_size
        self.use_sigmoid = use_sigmoid
        self.batches = math.floor(410 / batch_size)
        self.alpha = alpha
        self.epochs = epochs
        self.W0 = np.array([[random.randint(0, 10) / 10 for y in range(0, no_neurons)] for x in range(0, 2)])
        self.W1 = np.array([[random.randint(0, 10) / 10 for y in range(0, no_neurons)] for x in range(0, no_neurons)])
        self.W2 = np.array([[random.randint(0, 10) / 10] for x in range(0, no_neurons)])
        self.bias0 = np.array([[0.1 for x in range(0, no_neurons)]])
        self.bias1 = np.array([[0.1 for x in range(0, no_neurons)]])
        self.bias2 = 0.1
        self.Loss_Function = []
        self.iteration_n = []
        data = pd.read_csv('HW3Atrain.csv')
        test = pd.read_csv('HW3Avalidate.csv')
        x = data.iloc[:, 0:2]
        x_test = test.iloc[:, 0:2]
        self.Y_test = test.iloc[:, -1]
        self.Y = data.iloc[:, -1]
        x = self.min_max_scale(x)
        x_t = self.min_max_scale(x_test)
        self.X_array_test = np.array(x_t)
        self.X_array = np.array(x)

        self.loss_epochs = []
        self.loss_val_epochs = []
        
        self.gradient_W2 = []
        self.gradient_W1 = []
        self.gradient_W0 = []
        self.gradient_b2 = []
        self.gradient_b1 = []
        self.gradient_b0 = []
        self.loss_function = []
        self.loss_function_val = []

        self.avg_gradient_W2 = np.ndarray([])
        self.avg_gradient_W1 = np.ndarray([])
        self.avg_gradient_W0 = np.ndarray([])
        self.avg_gradient_b2 = np.ndarray([])
        self.avg_gradient_b1 = np.ndarray([])
        self.avg_gradient_b0 = np.ndarray([])

        self.final_W2 = np.ndarray([])
        self.final_W1 = np.ndarray([])
        self.final_W0 = np.ndarray([])
        self.final_bias0 = np.array([])
        self.final_bias1 = np.array([])
        self.final_bias2 = np.array([])

        self.results = np.ndarray([])
        self.confusion_matrix = np.ndarray([])
        self.results_data_frame = pd.DataFrame()
        self.confusion_matrix_data_frame = pd.DataFrame()
        

    def cross_entropy(self, y_hat, y):
        return -(y * np.log(y_hat) + (1 - y) * np.log(1 - y_hat))

    def sigmoid(self, z):
        result = 1.0 / (1.0 + np.exp(-z))
        return result

    def relu_derivative(self, z):
        result = 1 * (z > 0)
        return result

    def relu(self, z):
        if np.isscalar(z):
            result = np.max((z, 0))
        else:
            zero_aux = np.zeros(z.shape)
            meta_z = np.stack((z, zero_aux), axis=-1)
            result = np.max(meta_z, axis=-1)
        return result

    def min_max_scale(self, x):
        x_array = np.array(x)
        for i in range(0, x.shape[1]):
            x_min = np.amin(x.iloc[:, i])
            x_max = np.amax(x.iloc[:, i])
            scale = x_max - x_min
            for j in range(0, x.shape[0]):
                x_array[j, i] = x.iloc[j, i] / scale - x_min / scale
        return x_array

    def train(self):
        avg_loss_function_epoch = []
        avg_loss_function_val_epoch = []
        self.loss_epochs = []
        self.loss_val_epochs = []
        for epoch in range(0, self.epochs):
            self.loss_epochs.append(np.mean(avg_loss_function_epoch))
            self.loss_val_epochs.append(np.mean(avg_loss_function_val_epoch))  
            if epoch != 0:
                print(f"\nAVG_LOSS_FUNCTION OF EPOCH {epoch} ON TRAINING SET: {np.mean(avg_loss_function_epoch)}")
                print(f"\nAVG_LOSS_FUNCTION OF EPOCH {epoch} ON VALIDATION SET: {np.mean(avg_loss_function_val_epoch)}")
            avg_loss_function_epoch = []
            avg_loss_function_val_epoch = []
            for batch in range(0, self.batches):
                self.gradient_W2 = []
                self.gradient_W1 = []
                self.gradient_W0 = []
                self.gradient_b2 = []
                self.gradient_b1 = []
                self.gradient_b0 = []
                self.avg_gradient_W2 = []
                self.avg_gradient_W1 = []
                self.avg_gradient_W0 = []
                self.avg_gradient_b2 = []
                self.avg_gradient_b1 = []
                self.avg_gradient_b0 = []
                self.loss_function = []
                self.loss_function_val = []
                self.loss_function_epoch = []
                avg_loss_function = []
                avg_loss_function_val = []
                start_at = batch * self.batch_size
                for i in range(start_at, start_at + self.batch_size):
                    x_input = self.X_array[[i]]
                    y_input = self.Y[i]
                    # print(f"\n Epoch {epoch+1}: Batch{batch+1} {i}:")
                    self.iteration(x_input, i, y_input)
                    if (i < 82) & (batch<=(82/self.batch_size)):
                        x_t_input = self.X_array_test[[i]]
                        y_t_input = self.Y_test[i]
                        self.iteration_val(x_t_input, i, y_t_input)

                # Calculating average of Loss Function for this batch
                avg_loss_function = sum(self.loss_function) / self.batch_size  # this is the loss function of the batch
                avg_loss_function_val = sum(self.loss_function_val) / self.batch_size
                avg_loss_function_epoch.append(avg_loss_function)  # we add it to the list of epoch's loss functions
                if batch<=(82/self.batch_size):
                    avg_loss_function_val_epoch.append(avg_loss_function_val)
                
                
                # Calculating average of all gradients of this batch
                self.avg_gradient_W2 = np.mean(self.gradient_W2, axis=0)
                self.avg_gradient_W1 = np.mean(self.gradient_W1, axis=0)
                self.avg_gradient_W0 = np.mean(self.gradient_W0, axis=0)
                self.avg_gradient_b2 = np.mean(self.gradient_b2, axis=0)
                self.avg_gradient_b1 = np.mean(self.gradient_b1, axis=0)
                self.avg_gradient_b0 = np.mean(self.gradient_b0, axis=0)

                # Updating Weights and Biases
                new_w2 = self.W2 - self.alpha * self.avg_gradient_W2
                new_b2 = self.bias2 - self.alpha * self.avg_gradient_b2
                new_w1 = self.W1 - self.alpha * self.avg_gradient_W1
                new_b1 = self.bias1 - self.alpha * self.avg_gradient_b1
                new_w0 = self.W0 - self.alpha * self.avg_gradient_W0
                new_b0 = self.bias0 - self.alpha * self.avg_gradient_b0
                self.W2 = new_w2
                self.W1 = new_w1
                self.W0 = new_w0
                self.bias2 = new_b2
                self.bias1 = new_b1
                self.bias0 = new_b0
                self.final_W2 = new_w2
                self.final_W1 = new_w1
                self.final_W0 = new_w0
                self.final_bias2 = new_b2
                self.final_bias1 = new_b1
                self.final_bias0 = new_b0


    def iteration(self, x_input, i, y_input):
        # Feed Forward + Gradient calculation for each training datapoint
        input_h0 = x_input.dot(self.W0) + self.bias0
        output_h0 = self.sigmoid(input_h0) if self.use_sigmoid else self.relu(input_h0)
        input_h1 = output_h0.dot(self.W1) + self.bias1
        output_h1 = self.sigmoid(input_h1) if self.use_sigmoid else self.relu(input_h1)
        input_sigmoid = output_h1.dot(self.W2) + self.bias2
        y_hat = self.sigmoid(input_sigmoid)

        # Calculating the Loss Function for this data point and adding it to the batch's loss
        self.loss_function.append(self.cross_entropy(y_hat, y_input))

        # Back Propagation - Calculating derivatives
        derivative_cross_entropy = -1 * (y_input / y_hat) + ((1 - y_input) / (1 - y_hat))
        derivative_sigmoid = y_hat * (1 - y_hat)
        if self.use_sigmoid:
            self.gradient_W2.append((derivative_cross_entropy * derivative_sigmoid * output_h1).T)
            self.gradient_W1.append(derivative_cross_entropy * derivative_sigmoid * self.W2.T * (output_h1 * (1 - output_h1)) * output_h0.T)
            self.gradient_W0.append(derivative_cross_entropy * derivative_sigmoid * (output_h1 * (1 - output_h1)) * self.W2.T.dot(self.W1.T) * (output_h0 * (1 - output_h0)) * x_input.T)
            self.gradient_b2.append(derivative_cross_entropy * derivative_sigmoid)
            self.gradient_b1.append(derivative_cross_entropy * derivative_sigmoid * self.W2.T * (output_h1 * (1 - output_h1)))
            self.gradient_b0.append(derivative_cross_entropy * derivative_sigmoid * (output_h1 * (1 - output_h1)) * self.W2.T.dot(self.W1.T) * (output_h0 * (1 - output_h0)))
        else:
            self.gradient_W2.append((derivative_cross_entropy * derivative_sigmoid * output_h1).T)
            self.gradient_W1.append(derivative_cross_entropy * derivative_sigmoid * self.W2.T *self.relu_derivative(input_h1) * output_h0.T)
            self.gradient_W0.append(derivative_cross_entropy * derivative_sigmoid *self.relu_derivative(input_h1) * self.W2.T.dot(self.W1.T) * self.relu_derivative(input_h0) * x_input.T)
            self.gradient_b2.append(derivative_cross_entropy * derivative_sigmoid)
            self.gradient_b1.append(derivative_cross_entropy * derivative_sigmoid *self.W2.T * self.relu_derivative(input_h1))
            self.gradient_b0.append(derivative_cross_entropy * derivative_sigmoid *self.relu_derivative(input_h1) * self.W2.T.dot(self.W1.T) * self.relu_derivative(input_h0))
        # print(f"loss_function of datapoint {i}: {cross_entropy(y_hat, Y_input)}")

    def predict(self) -> float:
        self.results = np.empty([self.X_array_test.shape[0], 7])
        self.confusion_matrix = np.empty([2, 2])
        for i in range(0, self.X_array_test.shape[0]):
            x_t_input = self.X_array_test[[i]]
            y_t_input = self.Y_test[i]
            self.iteration_ff(x_t_input, i, y_t_input)
        self.results_data_frame = pd.DataFrame(self.results)
        self.results_data_frame.columns = ('X0', 'X1', 'Y true', 'Y pred.', 'Cost', 'Prediction', 'Correct?')
        accuracy = sum(self.results_data_frame.iloc[:, 6]) / self.X_array_test.shape[0]
        avg_cost = np.mean(self.results_data_frame.iloc[:, 4])
        self.confusion_matrix[0, 0] = sum((self.results_data_frame.iloc[:, 2] == 1) & (self.results_data_frame.iloc[:, 5] == 1))
        self.confusion_matrix[0, 1] = sum((self.results_data_frame.iloc[:, 2] == 1) & (self.results_data_frame.iloc[:, 5] == 0))
        self.confusion_matrix[1, 0] = sum((self.results_data_frame.iloc[:, 2] == 0) & (self.results_data_frame.iloc[:, 5] == 1))
        self.confusion_matrix[1, 1] = sum((self.results_data_frame.iloc[:, 2] == 0) & (self.results_data_frame.iloc[:, 5] == 0))
        self.confusion_matrix_data_frame = pd.DataFrame(self.confusion_matrix).astype(int)
        self.confusion_matrix_data_frame.columns = ('Predicted Class= 1','Predicted Class= 0')
        self.confusion_matrix_data_frame.index = ('True Class= 1', 'True Class= 0')
        dict1 = {1.0: "Yes", 0.0: "No"}
        self.results_data_frame.iloc[:, 6].replace(dict1, inplace=True)
        print(self.results_data_frame)
        print(f"\n ACCURACY: {accuracy * 100} %")
        print(f"\n AVERAGE COST FUNCTION: {round(avg_cost, 4)}")
        print(f"\n --------------- \n\nCONFUSION MATRIX \n")
        print(self.confusion_matrix_data_frame)
        return accuracy

    def iteration_ff(self, x_t_input, i, y_t_input):
        input_h0 = x_t_input.dot(self.final_W0) + self.final_bias0
        output_h0 = self.sigmoid(input_h0) if self.use_sigmoid else self.relu(input_h0)
        input_h1 = output_h0.dot(self.final_W1) + self.final_bias1
        output_h1 = self.sigmoid(input_h1) if self.use_sigmoid else self.relu(input_h1)
        input_sigmoid = output_h1.dot(self.final_W2) + self.final_bias2
        y_hat = self.sigmoid(input_sigmoid)
        
        self.results[i, 0] = round(x_t_input[0][0], 3)
        self.results[i, 1] = round(x_t_input[0][1], 3)
        self.results[i, 2] = y_t_input
        self.results[i, 3] = round(y_hat[0][0], 3)
        self.results[i, 4] = round(self.cross_entropy(y_hat, y_t_input)[0][0], 3)
        if y_hat[0][0] > 0.5:
            self.results[i, 5] = 1
        else:
            self.results[i, 5] = 0
        if self.results[i, 2] == self.results[i, 5]:
            self.results[i, 6] = 1
        else:
            self.results[i, 6] = 0
    
    def iteration_val(self, x_t_input, i, y_t_input): #this function computes the loss on the validation datapoints
        input_h0 = x_t_input.dot(self.W0) + self.bias0
        output_h0 = self.sigmoid(input_h0) if self.use_sigmoid else self.relu(input_h0)
        input_h1 = output_h0.dot(self.W1) + self.bias1
        output_h1 = self.sigmoid(input_h1) if self.use_sigmoid else self.relu(input_h1)
        input_sigmoid = output_h1.dot(self.W2) + self.bias2
        y_hat = self.sigmoid(input_sigmoid)
        if i<82:
            self.loss_function_val.append(self.cross_entropy(y_hat, y_t_input)[0][0])
            #print(f"\n The loss of this validation point {i} is {self.cross_entropy(y_hat, y_t_input)[0][0]}")

# %%
HW3 = MLP(batch_size=10, alpha=0.05, epochs=200, no_neurons=10, use_sigmoid=False)

# %%
HW3.train()
# Out:
# C:\Users\Gabriel\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\Gabriel\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# AVG_LOSS_FUNCTION OF EPOCH 1 ON TRAINING SET: 1.2301758922582806
#
# AVG_LOSS_FUNCTION OF EPOCH 1 ON VALIDATION SET: 2.3136192674990115
#
# AVG_LOSS_FUNCTION OF EPOCH 2 ON TRAINING SET: 0.7209710792391947
#
# AVG_LOSS_FUNCTION OF EPOCH 2 ON VALIDATION SET: 0.6568626224855859
#
# AVG_LOSS_FUNCTION OF EPOCH 3 ON TRAINING SET: 0.7130397733839053
#
# AVG_LOSS_FUNCTION OF EPOCH 3 ON VALIDATION SET: 0.6488950667392164
#
# AVG_LOSS_FUNCTION OF EPOCH 4 ON TRAINING SET: 0.7053272088810868
#
# AVG_LOSS_FUNCTION OF EPOCH 4 ON VALIDATION SET: 0.6421471837046027
#
# AVG_LOSS_FUNCTION OF EPOCH 5 ON TRAINING SET: 0.6984077671852534
#
# AVG_LOSS_FUNCTION OF EPOCH 5 ON VALIDATION SET: 0.6361333210435601
#
# AVG_LOSS_FUNCTION OF EPOCH 6 ON TRAINING SET: 0.6903722510564199
#
# AVG_LOSS_FUNCTION OF EPOCH 6 ON VALIDATION SET: 0.6301121587861215
#
# AVG_LOSS_FUNCTION OF EPOCH 7 ON TRAINING SET: 0.6790918309719204
#
# AVG_LOSS_FUNCTION OF EPOCH 7 ON VALIDATION SET: 0.6218656642432084
#
# AVG_LOSS_FUNCTION OF EPOCH 8 ON TRAINING SET: 0.6654168627476877
#
# AVG_LOSS_FUNCTION OF EPOCH 8 ON VALIDATION SET: 0.6099033235841153
#
# AVG_LOSS_FUNCTION OF EPOCH 9 ON TRAINING SET: 0.6517341707571048
#
# AVG_LOSS_FUNCTION OF EPOCH 9 ON VALIDATION SET: 0.5974436444858401
#
# AVG_LOSS_FUNCTION OF EPOCH 10 ON TRAINING SET: 0.6362551619188346
#
# AVG_LOSS_FUNCTION OF EPOCH 10 ON VALIDATION SET: 0.5836129176417778
#
# AVG_LOSS_FUNCTION OF EPOCH 11 ON TRAINING SET: 0.6183771916833671
#
# AVG_LOSS_FUNCTION OF EPOCH 11 ON VALIDATION SET: 0.5674089811400674
#
# AVG_LOSS_FUNCTION OF EPOCH 12 ON TRAINING SET: 0.5987054087836388
#
# AVG_LOSS_FUNCTION OF EPOCH 12 ON VALIDATION SET: 0.5492657062884797
#
# AVG_LOSS_FUNCTION OF EPOCH 13 ON TRAINING SET: 0.5773879235254163
#
# AVG_LOSS_FUNCTION OF EPOCH 13 ON VALIDATION SET: 0.5293180012214116
#
# AVG_LOSS_FUNCTION OF EPOCH 14 ON TRAINING SET: 0.5540736217704837
#
# AVG_LOSS_FUNCTION OF EPOCH 14 ON VALIDATION SET: 0.5072052238652691
#
# AVG_LOSS_FUNCTION OF EPOCH 15 ON TRAINING SET: 0.529136000447318
#
# AVG_LOSS_FUNCTION OF EPOCH 15 ON VALIDATION SET: 0.48401534292202913
#
# AVG_LOSS_FUNCTION OF EPOCH 16 ON TRAINING SET: 0.5028319695866816
#
# AVG_LOSS_FUNCTION OF EPOCH 16 ON VALIDATION SET: 0.4587974864968586
#
# AVG_LOSS_FUNCTION OF EPOCH 17 ON TRAINING SET: 0.4749507282612132
#
# AVG_LOSS_FUNCTION OF EPOCH 17 ON VALIDATION SET: 0.43269886339641883
#
# AVG_LOSS_FUNCTION OF EPOCH 18 ON TRAINING SET: 0.445487527262513
#
# AVG_LOSS_FUNCTION OF EPOCH 18 ON VALIDATION SET: 0.4050239425269503
#
# AVG_LOSS_FUNCTION OF EPOCH 19 ON TRAINING SET: 0.4153246284677643
#
# AVG_LOSS_FUNCTION OF EPOCH 19 ON VALIDATION SET: 0.3769355910939105
#
# AVG_LOSS_FUNCTION OF EPOCH 20 ON TRAINING SET: 0.38536272034311075
#
# AVG_LOSS_FUNCTION OF EPOCH 20 ON VALIDATION SET: 0.3492327150099862
#
# AVG_LOSS_FUNCTION OF EPOCH 21 ON TRAINING SET: 0.357040194192633
#
# AVG_LOSS_FUNCTION OF EPOCH 21 ON VALIDATION SET: 0.3229551836793443
#
# AVG_LOSS_FUNCTION OF EPOCH 22 ON TRAINING SET: 0.3308881666379182
#
# AVG_LOSS_FUNCTION OF EPOCH 22 ON VALIDATION SET: 0.2986894355132166
#
# AVG_LOSS_FUNCTION OF EPOCH 23 ON TRAINING SET: 0.3078379098267281
#
# AVG_LOSS_FUNCTION OF EPOCH 23 ON VALIDATION SET: 0.27685162938246893
#
# AVG_LOSS_FUNCTION OF EPOCH 24 ON TRAINING SET: 0.2876111891769876
#
# AVG_LOSS_FUNCTION OF EPOCH 24 ON VALIDATION SET: 0.25793889910794154
#
# AVG_LOSS_FUNCTION OF EPOCH 25 ON TRAINING SET: 0.27051194997158334
#
# AVG_LOSS_FUNCTION OF EPOCH 25 ON VALIDATION SET: 0.24126273046767288
#
# AVG_LOSS_FUNCTION OF EPOCH 26 ON TRAINING SET: 0.25540498758732977
#
# AVG_LOSS_FUNCTION OF EPOCH 26 ON VALIDATION SET: 0.22725033524059787
#
# AVG_LOSS_FUNCTION OF EPOCH 27 ON TRAINING SET: 0.24237679878031548
#
# AVG_LOSS_FUNCTION OF EPOCH 27 ON VALIDATION SET: 0.21484539813257716
#
# AVG_LOSS_FUNCTION OF EPOCH 28 ON TRAINING SET: 0.2316107564924311
#
# AVG_LOSS_FUNCTION OF EPOCH 28 ON VALIDATION SET: 0.2038551219433786
#
# AVG_LOSS_FUNCTION OF EPOCH 29 ON TRAINING SET: 0.22277748969622618
#
# AVG_LOSS_FUNCTION OF EPOCH 29 ON VALIDATION SET: 0.1951463175862126
#
# AVG_LOSS_FUNCTION OF EPOCH 30 ON TRAINING SET: 0.21526011062052722
#
# AVG_LOSS_FUNCTION OF EPOCH 30 ON VALIDATION SET: 0.1877031281026487
#
# AVG_LOSS_FUNCTION OF EPOCH 31 ON TRAINING SET: 0.20917354388998488
#
# AVG_LOSS_FUNCTION OF EPOCH 31 ON VALIDATION SET: 0.18571674398513427
#
# AVG_LOSS_FUNCTION OF EPOCH 32 ON TRAINING SET: 0.2036183133165665
#
# AVG_LOSS_FUNCTION OF EPOCH 32 ON VALIDATION SET: 0.18076889183406958
#
# AVG_LOSS_FUNCTION OF EPOCH 33 ON TRAINING SET: 0.19890867622483707
#
# AVG_LOSS_FUNCTION OF EPOCH 33 ON VALIDATION SET: 0.17730701420645353
#
# AVG_LOSS_FUNCTION OF EPOCH 34 ON TRAINING SET: 0.19522175929390784
#
# AVG_LOSS_FUNCTION OF EPOCH 34 ON VALIDATION SET: 0.1744463195711471
#
# AVG_LOSS_FUNCTION OF EPOCH 35 ON TRAINING SET: 0.1918559971282393
#
# AVG_LOSS_FUNCTION OF EPOCH 35 ON VALIDATION SET: 0.17333485690948394
#
# AVG_LOSS_FUNCTION OF EPOCH 36 ON TRAINING SET: 0.18921172715705872
#
# AVG_LOSS_FUNCTION OF EPOCH 36 ON VALIDATION SET: 0.17172508124700842
#
# AVG_LOSS_FUNCTION OF EPOCH 37 ON TRAINING SET: 0.18666162615114343
#
# AVG_LOSS_FUNCTION OF EPOCH 37 ON VALIDATION SET: 0.17050931145222262
#
# AVG_LOSS_FUNCTION OF EPOCH 38 ON TRAINING SET: 0.1846823364860809
#
# AVG_LOSS_FUNCTION OF EPOCH 38 ON VALIDATION SET: 0.16961414827371055
#
# AVG_LOSS_FUNCTION OF EPOCH 39 ON TRAINING SET: 0.18322425177653603
#
# AVG_LOSS_FUNCTION OF EPOCH 39 ON VALIDATION SET: 0.16895590080361722
#
# AVG_LOSS_FUNCTION OF EPOCH 40 ON TRAINING SET: 0.18161733028405738
#
# AVG_LOSS_FUNCTION OF EPOCH 40 ON VALIDATION SET: 0.16866462794253298
#
# AVG_LOSS_FUNCTION OF EPOCH 41 ON TRAINING SET: 0.18041607905179555
#
# AVG_LOSS_FUNCTION OF EPOCH 41 ON VALIDATION SET: 0.16811247363926107
#
# AVG_LOSS_FUNCTION OF EPOCH 42 ON TRAINING SET: 0.17942548448229606
#
# AVG_LOSS_FUNCTION OF EPOCH 42 ON VALIDATION SET: 0.1678398393484676
#
# AVG_LOSS_FUNCTION OF EPOCH 43 ON TRAINING SET: 0.17846709467960237
#
# AVG_LOSS_FUNCTION OF EPOCH 43 ON VALIDATION SET: 0.16781685043343172
#
# AVG_LOSS_FUNCTION OF EPOCH 44 ON TRAINING SET: 0.17762466806672522
#
# AVG_LOSS_FUNCTION OF EPOCH 44 ON VALIDATION SET: 0.16773627888793408
#
# AVG_LOSS_FUNCTION OF EPOCH 45 ON TRAINING SET: 0.17696060000154126
#
# AVG_LOSS_FUNCTION OF EPOCH 45 ON VALIDATION SET: 0.1680468657461549
#
# AVG_LOSS_FUNCTION OF EPOCH 46 ON TRAINING SET: 0.17638101429353722
#
# AVG_LOSS_FUNCTION OF EPOCH 46 ON VALIDATION SET: 0.168020631764587
#
# AVG_LOSS_FUNCTION OF EPOCH 47 ON TRAINING SET: 0.17585494119747938
#
# AVG_LOSS_FUNCTION OF EPOCH 47 ON VALIDATION SET: 0.1684977662019028
#
# AVG_LOSS_FUNCTION OF EPOCH 48 ON TRAINING SET: 0.17544289919096898
#
# AVG_LOSS_FUNCTION OF EPOCH 48 ON VALIDATION SET: 0.16868107175813316
#
# AVG_LOSS_FUNCTION OF EPOCH 49 ON TRAINING SET: 0.1749664665243924
#
# AVG_LOSS_FUNCTION OF EPOCH 49 ON VALIDATION SET: 0.16909423679190116
#
# AVG_LOSS_FUNCTION OF EPOCH 50 ON TRAINING SET: 0.1746609071906137
#
# AVG_LOSS_FUNCTION OF EPOCH 50 ON VALIDATION SET: 0.16938674343155047
#
# AVG_LOSS_FUNCTION OF EPOCH 51 ON TRAINING SET: 0.1743336702127615
#
# AVG_LOSS_FUNCTION OF EPOCH 51 ON VALIDATION SET: 0.16994324049934958
#
# AVG_LOSS_FUNCTION OF EPOCH 52 ON TRAINING SET: 0.1741945768471232
#
# AVG_LOSS_FUNCTION OF EPOCH 52 ON VALIDATION SET: 0.16995860913550775
#
# AVG_LOSS_FUNCTION OF EPOCH 53 ON TRAINING SET: 0.1739104924665023
#
# AVG_LOSS_FUNCTION OF EPOCH 53 ON VALIDATION SET: 0.1705955231723192
#
# AVG_LOSS_FUNCTION OF EPOCH 54 ON TRAINING SET: 0.17381730364581852
#
# AVG_LOSS_FUNCTION OF EPOCH 54 ON VALIDATION SET: 0.17083229131499308
#
# AVG_LOSS_FUNCTION OF EPOCH 55 ON TRAINING SET: 0.17363818188001195
#
# AVG_LOSS_FUNCTION OF EPOCH 55 ON VALIDATION SET: 0.1712612277928837
#
# AVG_LOSS_FUNCTION OF EPOCH 56 ON TRAINING SET: 0.17324905726957465
#
# AVG_LOSS_FUNCTION OF EPOCH 56 ON VALIDATION SET: 0.17178929885725286
#
# AVG_LOSS_FUNCTION OF EPOCH 57 ON TRAINING SET: 0.17310748324134614
#
# AVG_LOSS_FUNCTION OF EPOCH 57 ON VALIDATION SET: 0.17210904777495362
#
# AVG_LOSS_FUNCTION OF EPOCH 58 ON TRAINING SET: 0.17296757422329717
#
# AVG_LOSS_FUNCTION OF EPOCH 58 ON VALIDATION SET: 0.17247585926952644
#
# AVG_LOSS_FUNCTION OF EPOCH 59 ON TRAINING SET: 0.1728925844902188
#
# AVG_LOSS_FUNCTION OF EPOCH 59 ON VALIDATION SET: 0.17294126318520178
#
# AVG_LOSS_FUNCTION OF EPOCH 60 ON TRAINING SET: 0.17280906569352125
#
# AVG_LOSS_FUNCTION OF EPOCH 60 ON VALIDATION SET: 0.17321884909367313
# AVG_LOSS_FUNCTION OF EPOCH 61 ON TRAINING SET: 0.1726788072765049
#
# AVG_LOSS_FUNCTION OF EPOCH 61 ON VALIDATION SET: 0.17361007765286898
#
# AVG_LOSS_FUNCTION OF EPOCH 62 ON TRAINING SET: 0.17255947073921202
#
# AVG_LOSS_FUNCTION OF EPOCH 62 ON VALIDATION SET: 0.17400664944055197
#
# AVG_LOSS_FUNCTION OF EPOCH 63 ON TRAINING SET: 0.1724248512201348
#
# AVG_LOSS_FUNCTION OF EPOCH 63 ON VALIDATION SET: 0.17429087975162608
#
# AVG_LOSS_FUNCTION OF EPOCH 64 ON TRAINING SET: 0.17233802490344266
#
# AVG_LOSS_FUNCTION OF EPOCH 64 ON VALIDATION SET: 0.17464168859259446
#
# AVG_LOSS_FUNCTION OF EPOCH 65 ON TRAINING SET: 0.1721971794359869
#
# AVG_LOSS_FUNCTION OF EPOCH 65 ON VALIDATION SET: 0.17494986602837212
#
# AVG_LOSS_FUNCTION OF EPOCH 66 ON TRAINING SET: 0.17208223339445244
#
# AVG_LOSS_FUNCTION OF EPOCH 66 ON VALIDATION SET: 0.17533260409442333
#
# AVG_LOSS_FUNCTION OF EPOCH 67 ON TRAINING SET: 0.171972226689631
#
# AVG_LOSS_FUNCTION OF EPOCH 67 ON VALIDATION SET: 0.17556687289282535
#
# AVG_LOSS_FUNCTION OF EPOCH 68 ON TRAINING SET: 0.17181939776735414
#
# AVG_LOSS_FUNCTION OF EPOCH 68 ON VALIDATION SET: 0.17585523508778694
#
# AVG_LOSS_FUNCTION OF EPOCH 69 ON TRAINING SET: 0.1716893993520302
#
# AVG_LOSS_FUNCTION OF EPOCH 69 ON VALIDATION SET: 0.17615927442861626
#
# AVG_LOSS_FUNCTION OF EPOCH 70 ON TRAINING SET: 0.17155913160194927
#
# AVG_LOSS_FUNCTION OF EPOCH 70 ON VALIDATION SET: 0.1764888585959007
#
# AVG_LOSS_FUNCTION OF EPOCH 71 ON TRAINING SET: 0.17143711412596194
#
# AVG_LOSS_FUNCTION OF EPOCH 71 ON VALIDATION SET: 0.17670102576707014
#
# AVG_LOSS_FUNCTION OF EPOCH 72 ON TRAINING SET: 0.17127442852990113
#
# AVG_LOSS_FUNCTION OF EPOCH 72 ON VALIDATION SET: 0.17694194382904824
#
# AVG_LOSS_FUNCTION OF EPOCH 73 ON TRAINING SET: 0.17112029477838994
#
# AVG_LOSS_FUNCTION OF EPOCH 73 ON VALIDATION SET: 0.17729400669746814
#
# AVG_LOSS_FUNCTION OF EPOCH 74 ON TRAINING SET: 0.17100248956456265
#
# AVG_LOSS_FUNCTION OF EPOCH 74 ON VALIDATION SET: 0.17732628429536654
#
# AVG_LOSS_FUNCTION OF EPOCH 75 ON TRAINING SET: 0.17093709644303834
#
# AVG_LOSS_FUNCTION OF EPOCH 75 ON VALIDATION SET: 0.17762046905646836
#
# AVG_LOSS_FUNCTION OF EPOCH 76 ON TRAINING SET: 0.17068883271177884
#
# AVG_LOSS_FUNCTION OF EPOCH 76 ON VALIDATION SET: 0.17789068504114913
#
# AVG_LOSS_FUNCTION OF EPOCH 77 ON TRAINING SET: 0.17060595537298762
#
# AVG_LOSS_FUNCTION OF EPOCH 77 ON VALIDATION SET: 0.17803028540676896
#
# AVG_LOSS_FUNCTION OF EPOCH 78 ON TRAINING SET: 0.17045241593312083
#
# AVG_LOSS_FUNCTION OF EPOCH 78 ON VALIDATION SET: 0.17837057083323668
#
# AVG_LOSS_FUNCTION OF EPOCH 79 ON TRAINING SET: 0.17022430893549612
#
# AVG_LOSS_FUNCTION OF EPOCH 79 ON VALIDATION SET: 0.17836706856898038
#
# AVG_LOSS_FUNCTION OF EPOCH 80 ON TRAINING SET: 0.17010033744575276
#
# AVG_LOSS_FUNCTION OF EPOCH 80 ON VALIDATION SET: 0.17846367405507008
#
# AVG_LOSS_FUNCTION OF EPOCH 81 ON TRAINING SET: 0.16987580982217773
#
# AVG_LOSS_FUNCTION OF EPOCH 81 ON VALIDATION SET: 0.17865248840054362
#
# AVG_LOSS_FUNCTION OF EPOCH 82 ON TRAINING SET: 0.16971645471156396
#
# AVG_LOSS_FUNCTION OF EPOCH 82 ON VALIDATION SET: 0.17871893705327457
#
# AVG_LOSS_FUNCTION OF EPOCH 83 ON TRAINING SET: 0.16960696691276606
#
# AVG_LOSS_FUNCTION OF EPOCH 83 ON VALIDATION SET: 0.17895506165810873
#
# AVG_LOSS_FUNCTION OF EPOCH 84 ON TRAINING SET: 0.16945082989385796
#
# AVG_LOSS_FUNCTION OF EPOCH 84 ON VALIDATION SET: 0.17892672000023196
#
# AVG_LOSS_FUNCTION OF EPOCH 85 ON TRAINING SET: 0.16920750756054023
#
# AVG_LOSS_FUNCTION OF EPOCH 85 ON VALIDATION SET: 0.17902899960272128
#
# AVG_LOSS_FUNCTION OF EPOCH 86 ON TRAINING SET: 0.16909733279277347
#
# AVG_LOSS_FUNCTION OF EPOCH 86 ON VALIDATION SET: 0.1791956430162671
#
# AVG_LOSS_FUNCTION OF EPOCH 87 ON TRAINING SET: 0.16888085042306245
#
# AVG_LOSS_FUNCTION OF EPOCH 87 ON VALIDATION SET: 0.17909892112786113
#
# AVG_LOSS_FUNCTION OF EPOCH 88 ON TRAINING SET: 0.16875499936413085
#
# AVG_LOSS_FUNCTION OF EPOCH 88 ON VALIDATION SET: 0.179154032535195
#
# AVG_LOSS_FUNCTION OF EPOCH 89 ON TRAINING SET: 0.16851649712214473
#
# AVG_LOSS_FUNCTION OF EPOCH 89 ON VALIDATION SET: 0.17941130494624638
#
# AVG_LOSS_FUNCTION OF EPOCH 90 ON TRAINING SET: 0.16841245537428445
#
# AVG_LOSS_FUNCTION OF EPOCH 90 ON VALIDATION SET: 0.17917964939840583
#
# AVG_LOSS_FUNCTION OF EPOCH 91 ON TRAINING SET: 0.16816332526169767
#
# AVG_LOSS_FUNCTION OF EPOCH 91 ON VALIDATION SET: 0.1793369848981932
#
# AVG_LOSS_FUNCTION OF EPOCH 92 ON TRAINING SET: 0.16805907511204318
#
# AVG_LOSS_FUNCTION OF EPOCH 92 ON VALIDATION SET: 0.17947817642933972
#
# AVG_LOSS_FUNCTION OF EPOCH 93 ON TRAINING SET: 0.16783366044429254
#
# AVG_LOSS_FUNCTION OF EPOCH 93 ON VALIDATION SET: 0.1793379999722879
#
# AVG_LOSS_FUNCTION OF EPOCH 94 ON TRAINING SET: 0.167696291644873
#
# AVG_LOSS_FUNCTION OF EPOCH 94 ON VALIDATION SET: 0.1793734644203564
#
# AVG_LOSS_FUNCTION OF EPOCH 95 ON TRAINING SET: 0.1674723397529648
#
# AVG_LOSS_FUNCTION OF EPOCH 95 ON VALIDATION SET: 0.17962727011833113
#
# AVG_LOSS_FUNCTION OF EPOCH 96 ON TRAINING SET: 0.16735983243389002
#
# AVG_LOSS_FUNCTION OF EPOCH 96 ON VALIDATION SET: 0.1793533271977801
#
# AVG_LOSS_FUNCTION OF EPOCH 97 ON TRAINING SET: 0.1671194515681728
#
# AVG_LOSS_FUNCTION OF EPOCH 97 ON VALIDATION SET: 0.17962392478376976
#
# AVG_LOSS_FUNCTION OF EPOCH 98 ON TRAINING SET: 0.16700026428384218
#
# AVG_LOSS_FUNCTION OF EPOCH 98 ON VALIDATION SET: 0.17936004433864738
#
# AVG_LOSS_FUNCTION OF EPOCH 99 ON TRAINING SET: 0.16675369304421556
#
# AVG_LOSS_FUNCTION OF EPOCH 99 ON VALIDATION SET: 0.17946877540410014
#
# AVG_LOSS_FUNCTION OF EPOCH 100 ON TRAINING SET: 0.16664158248987448
#
# AVG_LOSS_FUNCTION OF EPOCH 100 ON VALIDATION SET: 0.1796247185090316
#
# AVG_LOSS_FUNCTION OF EPOCH 101 ON TRAINING SET: 0.1665061504074004
#
# AVG_LOSS_FUNCTION OF EPOCH 101 ON VALIDATION SET: 0.17944009795444585
#
# AVG_LOSS_FUNCTION OF EPOCH 102 ON TRAINING SET: 0.16628768349301043
#
# AVG_LOSS_FUNCTION OF EPOCH 102 ON VALIDATION SET: 0.17952534366994677
#
# AVG_LOSS_FUNCTION OF EPOCH 103 ON TRAINING SET: 0.16621943481930423
#
# AVG_LOSS_FUNCTION OF EPOCH 103 ON VALIDATION SET: 0.1793917465960405
#
# AVG_LOSS_FUNCTION OF EPOCH 104 ON TRAINING SET: 0.1659359952805528
#
# AVG_LOSS_FUNCTION OF EPOCH 104 ON VALIDATION SET: 0.17951932140946036
#
# AVG_LOSS_FUNCTION OF EPOCH 105 ON TRAINING SET: 0.16582780980306058
#
# AVG_LOSS_FUNCTION OF EPOCH 105 ON VALIDATION SET: 0.17928474062420016
#
# AVG_LOSS_FUNCTION OF EPOCH 106 ON TRAINING SET: 0.16568906363493868
#
# AVG_LOSS_FUNCTION OF EPOCH 106 ON VALIDATION SET: 0.17924349645909263
#
# AVG_LOSS_FUNCTION OF EPOCH 107 ON TRAINING SET: 0.16552470923652748
#
# AVG_LOSS_FUNCTION OF EPOCH 107 ON VALIDATION SET: 0.17944682997503258
#
# AVG_LOSS_FUNCTION OF EPOCH 108 ON TRAINING SET: 0.1653086304824428
#
# AVG_LOSS_FUNCTION OF EPOCH 108 ON VALIDATION SET: 0.17917427829213495
#
# AVG_LOSS_FUNCTION OF EPOCH 109 ON TRAINING SET: 0.1651910519161633
#
# AVG_LOSS_FUNCTION OF EPOCH 109 ON VALIDATION SET: 0.17927362055181098
#
# AVG_LOSS_FUNCTION OF EPOCH 110 ON TRAINING SET: 0.16503247712774988
#
# AVG_LOSS_FUNCTION OF EPOCH 110 ON VALIDATION SET: 0.17902726624967136
#
# AVG_LOSS_FUNCTION OF EPOCH 111 ON TRAINING SET: 0.1648488984956248
#
# AVG_LOSS_FUNCTION OF EPOCH 111 ON VALIDATION SET: 0.17916740429088812
#
# AVG_LOSS_FUNCTION OF EPOCH 112 ON TRAINING SET: 0.16465657554882399
#
# AVG_LOSS_FUNCTION OF EPOCH 112 ON VALIDATION SET: 0.17888264892981093
#
# AVG_LOSS_FUNCTION OF EPOCH 113 ON TRAINING SET: 0.16452214620941996
#
# AVG_LOSS_FUNCTION OF EPOCH 113 ON VALIDATION SET: 0.17899119413757492
#
# AVG_LOSS_FUNCTION OF EPOCH 114 ON TRAINING SET: 0.1643632247635218
#
# AVG_LOSS_FUNCTION OF EPOCH 114 ON VALIDATION SET: 0.17875488120837224
#
# AVG_LOSS_FUNCTION OF EPOCH 115 ON TRAINING SET: 0.1642003593587901
#
# AVG_LOSS_FUNCTION OF EPOCH 115 ON VALIDATION SET: 0.17893779539264354
#
# AVG_LOSS_FUNCTION OF EPOCH 116 ON TRAINING SET: 0.16399029171846444
#
# AVG_LOSS_FUNCTION OF EPOCH 116 ON VALIDATION SET: 0.17865180226348892
#
# AVG_LOSS_FUNCTION OF EPOCH 117 ON TRAINING SET: 0.16388061828938053
#
# AVG_LOSS_FUNCTION OF EPOCH 117 ON VALIDATION SET: 0.1787799666306915
#
# AVG_LOSS_FUNCTION OF EPOCH 118 ON TRAINING SET: 0.16371097042983399
#
# AVG_LOSS_FUNCTION OF EPOCH 118 ON VALIDATION SET: 0.1785323008001328
#
# AVG_LOSS_FUNCTION OF EPOCH 119 ON TRAINING SET: 0.16354693135194998
#
# AVG_LOSS_FUNCTION OF EPOCH 119 ON VALIDATION SET: 0.1787271713528724
#
# AVG_LOSS_FUNCTION OF EPOCH 120 ON TRAINING SET: 0.16336349823741975
#
# AVG_LOSS_FUNCTION OF EPOCH 120 ON VALIDATION SET: 0.17843714697874427
# AVG_LOSS_FUNCTION OF EPOCH 121 ON TRAINING SET: 0.16323894255396498
#
# AVG_LOSS_FUNCTION OF EPOCH 121 ON VALIDATION SET: 0.17857005722547548
#
# AVG_LOSS_FUNCTION OF EPOCH 122 ON TRAINING SET: 0.16309373972075591
#
# AVG_LOSS_FUNCTION OF EPOCH 122 ON VALIDATION SET: 0.1783205277925485
#
# AVG_LOSS_FUNCTION OF EPOCH 123 ON TRAINING SET: 0.1629164455259677
#
# AVG_LOSS_FUNCTION OF EPOCH 123 ON VALIDATION SET: 0.17852363635098578
#
# AVG_LOSS_FUNCTION OF EPOCH 124 ON TRAINING SET: 0.16273987454029573
#
# AVG_LOSS_FUNCTION OF EPOCH 124 ON VALIDATION SET: 0.17821754339012755
#
# AVG_LOSS_FUNCTION OF EPOCH 125 ON TRAINING SET: 0.16262387723898675
#
# AVG_LOSS_FUNCTION OF EPOCH 125 ON VALIDATION SET: 0.17836119673056247
#
# AVG_LOSS_FUNCTION OF EPOCH 126 ON TRAINING SET: 0.16248027730919226
#
# AVG_LOSS_FUNCTION OF EPOCH 126 ON VALIDATION SET: 0.17809343259672364
#
# AVG_LOSS_FUNCTION OF EPOCH 127 ON TRAINING SET: 0.16231947391693327
#
# AVG_LOSS_FUNCTION OF EPOCH 127 ON VALIDATION SET: 0.1783058791565483
#
# AVG_LOSS_FUNCTION OF EPOCH 128 ON TRAINING SET: 0.162146051288916
#
# AVG_LOSS_FUNCTION OF EPOCH 128 ON VALIDATION SET: 0.17798420776636725
#
# AVG_LOSS_FUNCTION OF EPOCH 129 ON TRAINING SET: 0.16203021765451422
#
# AVG_LOSS_FUNCTION OF EPOCH 129 ON VALIDATION SET: 0.17814141975928993
#
# AVG_LOSS_FUNCTION OF EPOCH 130 ON TRAINING SET: 0.16189625059841337
#
# AVG_LOSS_FUNCTION OF EPOCH 130 ON VALIDATION SET: 0.17785239481560478
#
# AVG_LOSS_FUNCTION OF EPOCH 131 ON TRAINING SET: 0.16175783625444987
#
# AVG_LOSS_FUNCTION OF EPOCH 131 ON VALIDATION SET: 0.17807956978470452
#
# AVG_LOSS_FUNCTION OF EPOCH 132 ON TRAINING SET: 0.1615798460733032
#
# AVG_LOSS_FUNCTION OF EPOCH 132 ON VALIDATION SET: 0.17773896142059067
#
# AVG_LOSS_FUNCTION OF EPOCH 133 ON TRAINING SET: 0.16147315382605668
#
# AVG_LOSS_FUNCTION OF EPOCH 133 ON VALIDATION SET: 0.1779064838330583
#
# AVG_LOSS_FUNCTION OF EPOCH 134 ON TRAINING SET: 0.16134775151011072
#
# AVG_LOSS_FUNCTION OF EPOCH 134 ON VALIDATION SET: 0.17761153480237468
#
# AVG_LOSS_FUNCTION OF EPOCH 135 ON TRAINING SET: 0.161193557133964
#
# AVG_LOSS_FUNCTION OF EPOCH 135 ON VALIDATION SET: 0.17784771746548286
#
# AVG_LOSS_FUNCTION OF EPOCH 136 ON TRAINING SET: 0.16102636963750896
#
# AVG_LOSS_FUNCTION OF EPOCH 136 ON VALIDATION SET: 0.17750792757270797
#
# AVG_LOSS_FUNCTION OF EPOCH 137 ON TRAINING SET: 0.1609295354677173
#
# AVG_LOSS_FUNCTION OF EPOCH 137 ON VALIDATION SET: 0.17766012896346825
#
# AVG_LOSS_FUNCTION OF EPOCH 138 ON TRAINING SET: 0.16080541236975446
#
# AVG_LOSS_FUNCTION OF EPOCH 138 ON VALIDATION SET: 0.17737248691235494
#
# AVG_LOSS_FUNCTION OF EPOCH 139 ON TRAINING SET: 0.16065916490963927
#
# AVG_LOSS_FUNCTION OF EPOCH 139 ON VALIDATION SET: 0.1776070180819617
#
# AVG_LOSS_FUNCTION OF EPOCH 140 ON TRAINING SET: 0.16050018078218223
#
# AVG_LOSS_FUNCTION OF EPOCH 140 ON VALIDATION SET: 0.17727447934585433
#
# AVG_LOSS_FUNCTION OF EPOCH 141 ON TRAINING SET: 0.1604031638725773
#
# AVG_LOSS_FUNCTION OF EPOCH 141 ON VALIDATION SET: 0.1774409631612777
#
# AVG_LOSS_FUNCTION OF EPOCH 142 ON TRAINING SET: 0.16027659463889446
#
# AVG_LOSS_FUNCTION OF EPOCH 142 ON VALIDATION SET: 0.17714395475584838
#
# AVG_LOSS_FUNCTION OF EPOCH 143 ON TRAINING SET: 0.16014789145845512
#
# AVG_LOSS_FUNCTION OF EPOCH 143 ON VALIDATION SET: 0.1773627364521751
#
# AVG_LOSS_FUNCTION OF EPOCH 144 ON TRAINING SET: 0.1599913970652335
#
# AVG_LOSS_FUNCTION OF EPOCH 144 ON VALIDATION SET: 0.17702570649627283
#
# AVG_LOSS_FUNCTION OF EPOCH 145 ON TRAINING SET: 0.1599058859646085
#
# AVG_LOSS_FUNCTION OF EPOCH 145 ON VALIDATION SET: 0.17723610509374457
#
# AVG_LOSS_FUNCTION OF EPOCH 146 ON TRAINING SET: 0.15976343892674305
#
# AVG_LOSS_FUNCTION OF EPOCH 146 ON VALIDATION SET: 0.1769240985773905
#
# AVG_LOSS_FUNCTION OF EPOCH 147 ON TRAINING SET: 0.15965507720122132
#
# AVG_LOSS_FUNCTION OF EPOCH 147 ON VALIDATION SET: 0.17717353685120762
#
# AVG_LOSS_FUNCTION OF EPOCH 148 ON TRAINING SET: 0.15949537592199675
#
# AVG_LOSS_FUNCTION OF EPOCH 148 ON VALIDATION SET: 0.17682403187185916
#
# AVG_LOSS_FUNCTION OF EPOCH 149 ON TRAINING SET: 0.15940879538583091
#
# AVG_LOSS_FUNCTION OF EPOCH 149 ON VALIDATION SET: 0.17701862426220802
#
# AVG_LOSS_FUNCTION OF EPOCH 150 ON TRAINING SET: 0.15928746798366014
#
# AVG_LOSS_FUNCTION OF EPOCH 150 ON VALIDATION SET: 0.1767225541329453
#
# AVG_LOSS_FUNCTION OF EPOCH 151 ON TRAINING SET: 0.15914343696473773
#
# AVG_LOSS_FUNCTION OF EPOCH 151 ON VALIDATION SET: 0.17696251727266168
#
# AVG_LOSS_FUNCTION OF EPOCH 152 ON TRAINING SET: 0.1590614907827208
#
# AVG_LOSS_FUNCTION OF EPOCH 152 ON VALIDATION SET: 0.17657656497710073
#
# AVG_LOSS_FUNCTION OF EPOCH 153 ON TRAINING SET: 0.1589425192458078
#
# AVG_LOSS_FUNCTION OF EPOCH 153 ON VALIDATION SET: 0.17689222467032611
#
# AVG_LOSS_FUNCTION OF EPOCH 154 ON TRAINING SET: 0.1587909392529739
#
# AVG_LOSS_FUNCTION OF EPOCH 154 ON VALIDATION SET: 0.17654153963311092
#
# AVG_LOSS_FUNCTION OF EPOCH 155 ON TRAINING SET: 0.15871964644279407
#
# AVG_LOSS_FUNCTION OF EPOCH 155 ON VALIDATION SET: 0.1767533556488786
#
# AVG_LOSS_FUNCTION OF EPOCH 156 ON TRAINING SET: 0.1585867506704624
#
# AVG_LOSS_FUNCTION OF EPOCH 156 ON VALIDATION SET: 0.1764405894457352
#
# AVG_LOSS_FUNCTION OF EPOCH 157 ON TRAINING SET: 0.15848965504947934
#
# AVG_LOSS_FUNCTION OF EPOCH 157 ON VALIDATION SET: 0.1767107620949081
#
# AVG_LOSS_FUNCTION OF EPOCH 158 ON TRAINING SET: 0.15834330929232357
#
# AVG_LOSS_FUNCTION OF EPOCH 158 ON VALIDATION SET: 0.17635880150398942
#
# AVG_LOSS_FUNCTION OF EPOCH 159 ON TRAINING SET: 0.15826705232633353
#
# AVG_LOSS_FUNCTION OF EPOCH 159 ON VALIDATION SET: 0.17658564235411836
#
# AVG_LOSS_FUNCTION OF EPOCH 160 ON TRAINING SET: 0.158154242681639
#
# AVG_LOSS_FUNCTION OF EPOCH 160 ON VALIDATION SET: 0.1762785354643389
#
# AVG_LOSS_FUNCTION OF EPOCH 161 ON TRAINING SET: 0.1580517320116721
#
# AVG_LOSS_FUNCTION OF EPOCH 161 ON VALIDATION SET: 0.17654788967534282
#
# AVG_LOSS_FUNCTION OF EPOCH 162 ON TRAINING SET: 0.1579104828260348
#
# AVG_LOSS_FUNCTION OF EPOCH 162 ON VALIDATION SET: 0.17619698924416494
#
# AVG_LOSS_FUNCTION OF EPOCH 163 ON TRAINING SET: 0.1578378491495922
#
# AVG_LOSS_FUNCTION OF EPOCH 163 ON VALIDATION SET: 0.17643367534355317
#
# AVG_LOSS_FUNCTION OF EPOCH 164 ON TRAINING SET: 0.15772754395601477
#
# AVG_LOSS_FUNCTION OF EPOCH 164 ON VALIDATION SET: 0.1761270271456049
#
# AVG_LOSS_FUNCTION OF EPOCH 165 ON TRAINING SET: 0.15762889174615155
#
# AVG_LOSS_FUNCTION OF EPOCH 165 ON VALIDATION SET: 0.17641712317892486
#
# AVG_LOSS_FUNCTION OF EPOCH 166 ON TRAINING SET: 0.15752982728164044
#
# AVG_LOSS_FUNCTION OF EPOCH 166 ON VALIDATION SET: 0.17630098144891002
#
# AVG_LOSS_FUNCTION OF EPOCH 167 ON TRAINING SET: 0.15739939129720804
#
# AVG_LOSS_FUNCTION OF EPOCH 167 ON VALIDATION SET: 0.17599731586437448
#
# AVG_LOSS_FUNCTION OF EPOCH 168 ON TRAINING SET: 0.1573316947657813
#
# AVG_LOSS_FUNCTION OF EPOCH 168 ON VALIDATION SET: 0.17624856850657591
#
# AVG_LOSS_FUNCTION OF EPOCH 169 ON TRAINING SET: 0.15719739968609753
#
# AVG_LOSS_FUNCTION OF EPOCH 169 ON VALIDATION SET: 0.17595830576096752
#
# AVG_LOSS_FUNCTION OF EPOCH 170 ON TRAINING SET: 0.15713323847583607
#
# AVG_LOSS_FUNCTION OF EPOCH 170 ON VALIDATION SET: 0.17620298531757353
#
# AVG_LOSS_FUNCTION OF EPOCH 171 ON TRAINING SET: 0.15702338376076336
#
# AVG_LOSS_FUNCTION OF EPOCH 171 ON VALIDATION SET: 0.1758987646598432
#
# AVG_LOSS_FUNCTION OF EPOCH 172 ON TRAINING SET: 0.15692981501639103
#
# AVG_LOSS_FUNCTION OF EPOCH 172 ON VALIDATION SET: 0.1761906395518131
#
# AVG_LOSS_FUNCTION OF EPOCH 173 ON TRAINING SET: 0.1567969261364427
#
# AVG_LOSS_FUNCTION OF EPOCH 173 ON VALIDATION SET: 0.17584857661538708
#
# AVG_LOSS_FUNCTION OF EPOCH 174 ON TRAINING SET: 0.15674027457962328
#
# AVG_LOSS_FUNCTION OF EPOCH 174 ON VALIDATION SET: 0.17610469616760677
#
# AVG_LOSS_FUNCTION OF EPOCH 175 ON TRAINING SET: 0.15663235951487117
#
# AVG_LOSS_FUNCTION OF EPOCH 175 ON VALIDATION SET: 0.17602438291691885
#
# AVG_LOSS_FUNCTION OF EPOCH 176 ON TRAINING SET: 0.1565489379466178
#
# AVG_LOSS_FUNCTION OF EPOCH 176 ON VALIDATION SET: 0.17571453084344857
#
# AVG_LOSS_FUNCTION OF EPOCH 177 ON TRAINING SET: 0.15644379876297687
#
# AVG_LOSS_FUNCTION OF EPOCH 177 ON VALIDATION SET: 0.1760351140064359
#
# AVG_LOSS_FUNCTION OF EPOCH 178 ON TRAINING SET: 0.15632343492585696
#
# AVG_LOSS_FUNCTION OF EPOCH 178 ON VALIDATION SET: 0.1757060575374319
#
# AVG_LOSS_FUNCTION OF EPOCH 179 ON TRAINING SET: 0.15626171153129167
#
# AVG_LOSS_FUNCTION OF EPOCH 179 ON VALIDATION SET: 0.17597445877590703
# AVG_LOSS_FUNCTION OF EPOCH 180 ON TRAINING SET: 0.15616383905121425
#
# AVG_LOSS_FUNCTION OF EPOCH 180 ON VALIDATION SET: 0.17566356268715763
#
# AVG_LOSS_FUNCTION OF EPOCH 181 ON TRAINING SET: 0.15607381408929788
#
# AVG_LOSS_FUNCTION OF EPOCH 181 ON VALIDATION SET: 0.17597223858993294
#
# AVG_LOSS_FUNCTION OF EPOCH 182 ON TRAINING SET: 0.15594950970809499
#
# AVG_LOSS_FUNCTION OF EPOCH 182 ON VALIDATION SET: 0.17587100710331327
#
# AVG_LOSS_FUNCTION OF EPOCH 183 ON TRAINING SET: 0.1559023708422841
#
# AVG_LOSS_FUNCTION OF EPOCH 183 ON VALIDATION SET: 0.17551582665416798
#
# AVG_LOSS_FUNCTION OF EPOCH 184 ON TRAINING SET: 0.15579857731351826
#
# AVG_LOSS_FUNCTION OF EPOCH 184 ON VALIDATION SET: 0.17586444026154832
#
# AVG_LOSS_FUNCTION OF EPOCH 185 ON TRAINING SET: 0.15567905428797035
#
# AVG_LOSS_FUNCTION OF EPOCH 185 ON VALIDATION SET: 0.17554648823057717
#
# AVG_LOSS_FUNCTION OF EPOCH 186 ON TRAINING SET: 0.15562870523046057
#
# AVG_LOSS_FUNCTION OF EPOCH 186 ON VALIDATION SET: 0.17580917500783497
#
# AVG_LOSS_FUNCTION OF EPOCH 187 ON TRAINING SET: 0.15553414931613024
#
# AVG_LOSS_FUNCTION OF EPOCH 187 ON VALIDATION SET: 0.17573130199634354
#
# AVG_LOSS_FUNCTION OF EPOCH 188 ON TRAINING SET: 0.1554455162617249
#
# AVG_LOSS_FUNCTION OF EPOCH 188 ON VALIDATION SET: 0.17541259696330902
#
# AVG_LOSS_FUNCTION OF EPOCH 189 ON TRAINING SET: 0.15535916222398669
#
# AVG_LOSS_FUNCTION OF EPOCH 189 ON VALIDATION SET: 0.17572012728652367
#
# AVG_LOSS_FUNCTION OF EPOCH 190 ON TRAINING SET: 0.15524474877509264
#
# AVG_LOSS_FUNCTION OF EPOCH 190 ON VALIDATION SET: 0.17539648214699474
#
# AVG_LOSS_FUNCTION OF EPOCH 191 ON TRAINING SET: 0.15519452686064505
#
# AVG_LOSS_FUNCTION OF EPOCH 191 ON VALIDATION SET: 0.1756736858928413
#
# AVG_LOSS_FUNCTION OF EPOCH 192 ON TRAINING SET: 0.15510102137487047
#
# AVG_LOSS_FUNCTION OF EPOCH 192 ON VALIDATION SET: 0.1756034836595954
#
# AVG_LOSS_FUNCTION OF EPOCH 193 ON TRAINING SET: 0.15503470673338768
#
# AVG_LOSS_FUNCTION OF EPOCH 193 ON VALIDATION SET: 0.17528626017195906
#
# AVG_LOSS_FUNCTION OF EPOCH 194 ON TRAINING SET: 0.15493888125795852
#
# AVG_LOSS_FUNCTION OF EPOCH 194 ON VALIDATION SET: 0.175615564900426
#
# AVG_LOSS_FUNCTION OF EPOCH 195 ON TRAINING SET: 0.1548272983922677
#
# AVG_LOSS_FUNCTION OF EPOCH 195 ON VALIDATION SET: 0.17527819199733524
#
# AVG_LOSS_FUNCTION OF EPOCH 196 ON TRAINING SET: 0.15478209437235368
#
# AVG_LOSS_FUNCTION OF EPOCH 196 ON VALIDATION SET: 0.17555952582411294
#
# AVG_LOSS_FUNCTION OF EPOCH 197 ON TRAINING SET: 0.1546933577751033
#
# AVG_LOSS_FUNCTION OF EPOCH 197 ON VALIDATION SET: 0.1754768571921215
#
# AVG_LOSS_FUNCTION OF EPOCH 198 ON TRAINING SET: 0.15460952230990724
#
# AVG_LOSS_FUNCTION OF EPOCH 198 ON VALIDATION SET: 0.17515810803796916
#
# AVG_LOSS_FUNCTION OF EPOCH 199 ON TRAINING SET: 0.15452976780968702
#
# AVG_LOSS_FUNCTION OF EPOCH 199 ON VALIDATION SET: 0.1754739349724424

# %%
HW3.predict()
# Out:
#        X0     X1  Y true  Y pred.   Cost  Prediction Correct?
# 0   0.683  0.796     0.0    0.002  0.002         0.0      Yes
# 1   0.689  0.394     1.0    0.895  0.111         1.0      Yes
# 2   0.053  0.621     1.0    0.787  0.239         1.0      Yes
# 3   0.918  0.753     0.0    0.001  0.001         0.0      Yes
# 4   0.369  0.075     0.0    0.011  0.011         0.0      Yes
# 5   0.760  0.069     1.0    1.000  0.000         1.0      Yes
# 6   0.126  0.755     1.0    0.979  0.022         1.0      Yes
# 7   0.020  0.727     0.0    0.961  3.241         1.0       No
# 8   0.555  0.433     1.0    0.822  0.195         1.0      Yes
# 9   0.273  0.370     0.0    0.046  0.047         0.0      Yes
# 10  0.559  0.239     1.0    0.901  0.104         1.0      Yes
# 11  0.920  0.793     0.0    0.000  0.000         0.0      Yes
# 12  0.328  0.735     1.0    0.974  0.026         1.0      Yes
# 13  0.698  0.166     1.0    1.000  0.000         1.0      Yes
# 14  0.879  0.067     1.0    1.000  0.000         1.0      Yes
# 15  0.799  0.018     1.0    1.000  0.000         1.0      Yes
# 16  0.268  0.813     1.0    0.993  0.007         1.0      Yes
# 17  0.153  0.859     1.0    0.997  0.003         1.0      Yes
# 18  0.769  0.694     0.0    0.007  0.007         0.0      Yes
# 19  0.107  0.179     0.0    0.007  0.007         0.0      Yes
# 20  0.609  0.086     1.0    0.990  0.010         1.0      Yes
# 21  0.400  0.191     0.0    0.018  0.019         0.0      Yes
# 22  0.160  0.949     1.0    0.999  0.001         1.0      Yes
# 23  0.877  0.760     0.0    0.001  0.001         0.0      Yes
# 24  0.301  0.308     0.0    0.021  0.021         0.0      Yes
# 25  0.215  0.797     1.0    0.991  0.009         1.0      Yes
# 26  0.952  0.955     0.0    0.000  0.000         0.0      Yes
# 27  0.042  0.097     0.0    0.007  0.007         0.0      Yes
# 28  0.071  0.712     1.0    0.952  0.050         1.0      Yes
# 29  0.398  0.563     1.0    0.641  0.444         1.0      Yes
# ..    ...    ...     ...      ...    ...         ...      ...
# 52  0.031  0.428     0.0    0.098  0.103         0.0      Yes
# 53  0.696  0.088     1.0    1.000  0.000         1.0      Yes
# 54  0.979  0.943     0.0    0.000  0.000         0.0      Yes
# 55  0.754  0.136     1.0    1.000  0.000         1.0      Yes
# 56  0.073  0.862     1.0    0.997  0.003         1.0      Yes
# 57  0.646  0.915     1.0    0.000  7.654         0.0       No
# 58  0.327  0.000     0.0    0.008  0.008         0.0      Yes
# 59  0.154  1.000     1.0    1.000  0.000         1.0      Yes
# 60  0.357  0.449     0.0    0.176  0.194         0.0      Yes
# 61  0.707  0.873     0.0    0.000  0.000         0.0      Yes
# 62  0.952  0.276     1.0    0.979  0.021         1.0      Yes
# 63  0.614  0.837     0.0    0.003  0.003         0.0      Yes
# 64  0.034  0.025     0.0    0.007  0.007         0.0      Yes
# 65  0.264  0.561     1.0    0.603  0.506         1.0      Yes
# 66  0.297  0.590     1.0    0.727  0.319         1.0      Yes
# 67  0.920  0.202     1.0    0.997  0.003         1.0      Yes
# 68  0.228  0.936     1.0    0.999  0.001         1.0      Yes
# 69  0.215  0.355     0.0    0.033  0.034         0.0      Yes
# 70  0.741  0.785     0.0    0.002  0.002         0.0      Yes
# 71  0.593  0.002     1.0    0.991  0.009         1.0      Yes
# 72  0.094  0.149     0.0    0.007  0.007         0.0      Yes
# 73  0.261  0.895     1.0    0.998  0.002         1.0      Yes
# 74  0.906  0.691     0.0    0.002  0.002         0.0      Yes
# 75  0.402  0.336     0.0    0.044  0.045         0.0      Yes
# 76  0.156  0.732     1.0    0.968  0.032         1.0      Yes
# 77  0.953  0.659     0.0    0.004  0.004         0.0      Yes
# 78  0.844  0.635     0.0    0.011  0.011         0.0      Yes
# 79  0.374  0.635     1.0    0.866  0.144         1.0      Yes
# 80  0.057  0.391     0.0    0.054  0.055         0.0      Yes
# 81  0.590  0.285     1.0    0.966  0.034         1.0      Yes
#
# [82 rows x 7 columns]
#
#  ACCURACY: 97.5609756097561 %
#
#  AVERAGE COST FUNCTION: 0.187
#
#  ---------------
#
# CONFUSION MATRIX
#
#                Predicted Class= 1  Predicted Class= 0
# True Class= 1                  40                   1
# True Class= 0                   1                  40
# 0.975609756097561

# %% [markdown]
# ### Plots

# %%
Validation_Set = np.empty(HW3.epochs-1)
for i in range (1,HW3.epochs):
    Validation_Set[i-1] = HW3.loss_val_epochs[i]

# %%
Training_Set = np.empty(HW3.epochs-1)
for i in range (1,HW3.epochs):
    Training_Set[i-1] = HW3.loss_epochs[i]

# %%
epochs = np.arange(HW3.epochs-1)

# %%
plt.figure(figsize=(20,10))
plt.plot(epochs, Training_Set, color='Blue')
plt.yticks(np.arange(0,1.1,0.1))
plt.xticks(np.arange(0,210,10))
plt.title('Loss Function (Training Set)', fontsize=25)
plt.xlabel('Epoch #', fontsize=14)
plt.ylabel('Avg. Cross-Entropy', fontsize=14)
# Out:
# Text(0, 0.5, 'Avg. Cross-Entropy')

# %%
plt.figure(figsize=(20,10))
plt.plot(epochs, Validation_Set, color='Blue')
plt.yticks(np.arange(0,1.7,0.1))
plt.xticks(np.arange(0,210,10))
plt.title('Loss Function (Validation Set)', fontsize=25)
plt.xlabel('Epoch #', fontsize=14)
plt.ylabel('Avg. Cross-Entropy', fontsize=14)
# Out:
# Text(0, 0.5, 'Avg. Cross-Entropy')
