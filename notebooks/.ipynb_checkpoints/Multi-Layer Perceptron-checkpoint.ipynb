# %%
import numpy as np
import pandas as pd
import os
import random
import math
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
class MLP:
    def __init__(self, batch_size, alpha, epochs, no_neurons, use_sigmoid: bool):
        self.batch_size = batch_size
        self.use_sigmoid = use_sigmoid
        self.batches = math.floor(410 / batch_size)
        self.alpha = alpha
        self.epochs = epochs
        self.W0 = np.array([[random.randint(0, 10) / 10 for y in range(0, no_neurons)] for x in range(0, 2)])
        self.W1 = np.array([[random.randint(0, 10) / 10 for y in range(0, no_neurons)] for x in range(0, no_neurons)])
        self.W2 = np.array([[random.randint(0, 10) / 10] for x in range(0, no_neurons)])
        self.bias0 = np.array([[0.1 for x in range(0, no_neurons)]])
        self.bias1 = np.array([[0.1 for x in range(0, no_neurons)]])
        self.bias2 = 0.1
        self.Loss_Function = []
        self.iteration_n = []
        data = pd.read_csv('data/HW3Atrain.csv')
        test = pd.read_csv('data/HW3Avalidate.csv')
        x = data.iloc[:, 0:2]
        x_test = test.iloc[:, 0:2]
        self.Y_test = test.iloc[:, -1]
        self.Y = data.iloc[:, -1]
        x = self.min_max_scale(x)
        x_t = self.min_max_scale(x_test)
        self.X_array_test = np.array(x_t)
        self.X_array = np.array(x)

        self.loss_epochs = []; self.loss_val_epochs = []; self.gradient_W2 = []; self.gradient_W1 = []; self.gradient_W0 = []
        self.gradient_b2 = []; self.gradient_b1 = []; self.gradient_b0 = []; self.loss_function = []; self.loss_function_val = []
        self.avg_gradient_W2 = np.ndarray([]); self.avg_gradient_W1 = np.ndarray([]); self.avg_gradient_W0 = np.ndarray([])
        self.avg_gradient_b2 = np.ndarray([]); self.avg_gradient_b1 = np.ndarray([]); self.avg_gradient_b0 = np.ndarray([])
        self.final_W2 = np.ndarray([]); self.final_W1 = np.ndarray([]); self.final_W0 = np.ndarray([])
        self.final_bias0 = np.array([]); self.final_bias1 = np.array([]); self.final_bias2 = np.array([])
        self.results = np.ndarray([]); self.confusion_matrix = np.ndarray([]); self.results_data_frame = pd.DataFrame()
        self.confusion_matrix_data_frame = pd.DataFrame()
        

    def cross_entropy(self, y_hat, y):
        return -(y * np.log(y_hat) + (1 - y) * np.log(1 - y_hat))

    def sigmoid(self, z):
        result = 1.0 / (1.0 + np.exp(-z))
        return result

    def relu_derivative(self, z):
        result = 1 * (z > 0)
        return result

    def relu(self, z):
        if np.isscalar(z):
            result = np.max((z, 0))
        else:
            zero_aux = np.zeros(z.shape)
            meta_z = np.stack((z, zero_aux), axis=-1)
            result = np.max(meta_z, axis=-1)
        return result

    def min_max_scale(self, x):
        x_array = np.array(x)
        for i in range(0, x.shape[1]):
            x_min = np.amin(x.iloc[:, i])
            x_max = np.amax(x.iloc[:, i])
            scale = x_max - x_min
            for j in range(0, x.shape[0]):
                x_array[j, i] = x.iloc[j, i] / scale - x_min / scale
        return x_array

    def train(self):
        avg_loss_function_epoch = []
        avg_loss_function_val_epoch = []
        self.loss_epochs = []
        self.loss_val_epochs = []
        for epoch in range(0, self.epochs):
            self.loss_epochs.append(np.mean(avg_loss_function_epoch))
            self.loss_val_epochs.append(np.mean(avg_loss_function_val_epoch))  
            if epoch != 0:
                print(f"\nAVG_LOSS_FUNCTION OF EPOCH {epoch} ON TRAINING SET: {np.mean(avg_loss_function_epoch)}")
                print(f"\nAVG_LOSS_FUNCTION OF EPOCH {epoch} ON VALIDATION SET: {np.mean(avg_loss_function_val_epoch)}")
            avg_loss_function_epoch = []
            avg_loss_function_val_epoch = []
            for batch in range(0, self.batches):
                self.gradient_W2 = []; self.gradient_W1 = []; self.gradient_W0 = []; self.gradient_b2 = []
                self.gradient_b1 = []; self.gradient_b0 = []; self.avg_gradient_W2 = []; self.avg_gradient_W1 = []
                self.avg_gradient_W0 = []; self.avg_gradient_b2 = []; self.avg_gradient_b1 = []; self.avg_gradient_b0 = []
                self.loss_function = []; self.loss_function_val = []; self.loss_function_epoch = []
                avg_loss_function = []; avg_loss_function_val = []
                
                start_at = batch * self.batch_size
                for i in range(start_at, start_at + self.batch_size):
                    x_input = self.X_array[[i]]
                    y_input = self.Y[i]
                    self.iteration(x_input, i, y_input)
                    if (i < 82) & (batch<=(82/self.batch_size)):
                        x_t_input = self.X_array_test[[i]]
                        y_t_input = self.Y_test[i]
                        self.iteration_val(x_t_input, i, y_t_input)

                # Calculating average of Loss Function for this batch
                avg_loss_function = sum(self.loss_function) / self.batch_size  # this is the loss function of the batch
                avg_loss_function_val = sum(self.loss_function_val) / self.batch_size
                avg_loss_function_epoch.append(avg_loss_function)  # we add it to the list of epoch's loss functions
                if batch<=(82/self.batch_size):
                    avg_loss_function_val_epoch.append(avg_loss_function_val)
                
                
                # Calculating average of all gradients of this batch
                self.avg_gradient_W2 = np.mean(self.gradient_W2, axis=0)
                self.avg_gradient_W1 = np.mean(self.gradient_W1, axis=0)
                self.avg_gradient_W0 = np.mean(self.gradient_W0, axis=0)
                self.avg_gradient_b2 = np.mean(self.gradient_b2, axis=0)
                self.avg_gradient_b1 = np.mean(self.gradient_b1, axis=0)
                self.avg_gradient_b0 = np.mean(self.gradient_b0, axis=0)

                # Updating Weights and Biases
                new_w2 = self.W2 - self.alpha * self.avg_gradient_W2
                new_b2 = self.bias2 - self.alpha * self.avg_gradient_b2
                new_w1 = self.W1 - self.alpha * self.avg_gradient_W1
                new_b1 = self.bias1 - self.alpha * self.avg_gradient_b1
                new_w0 = self.W0 - self.alpha * self.avg_gradient_W0
                new_b0 = self.bias0 - self.alpha * self.avg_gradient_b0
                self.W2 = new_w2
                self.W1 = new_w1
                self.W0 = new_w0
                self.bias2 = new_b2
                self.bias1 = new_b1
                self.bias0 = new_b0
                self.final_W2 = new_w2
                self.final_W1 = new_w1
                self.final_W0 = new_w0
                self.final_bias2 = new_b2
                self.final_bias1 = new_b1
                self.final_bias0 = new_b0


    def iteration(self, x_input, i, y_input):
        # Feed Forward + Gradient calculation for each training datapoint
        input_h0 = x_input.dot(self.W0) + self.bias0
        output_h0 = self.sigmoid(input_h0) if self.use_sigmoid else self.relu(input_h0)
        input_h1 = output_h0.dot(self.W1) + self.bias1
        output_h1 = self.sigmoid(input_h1) if self.use_sigmoid else self.relu(input_h1)
        input_sigmoid = output_h1.dot(self.W2) + self.bias2
        y_hat = self.sigmoid(input_sigmoid)

        # Calculating the Loss Function for this data point and adding it to the batch's loss
        self.loss_function.append(self.cross_entropy(y_hat, y_input))

        # Back Propagation - Calculating derivatives
        derivative_cross_entropy = -1 * (y_input / y_hat) + ((1 - y_input) / (1 - y_hat))
        derivative_sigmoid = y_hat * (1 - y_hat)
        if self.use_sigmoid:
            self.gradient_W2.append((derivative_cross_entropy * derivative_sigmoid * output_h1).T)
            self.gradient_W1.append(derivative_cross_entropy * derivative_sigmoid * self.W2.T * (output_h1 * (1 - output_h1)) * output_h0.T)
            self.gradient_W0.append(derivative_cross_entropy * derivative_sigmoid * (output_h1 * (1 - output_h1)) * self.W2.T.dot(self.W1.T) * (output_h0 * (1 - output_h0)) * x_input.T)
            self.gradient_b2.append(derivative_cross_entropy * derivative_sigmoid)
            self.gradient_b1.append(derivative_cross_entropy * derivative_sigmoid * self.W2.T * (output_h1 * (1 - output_h1)))
            self.gradient_b0.append(derivative_cross_entropy * derivative_sigmoid * (output_h1 * (1 - output_h1)) * self.W2.T.dot(self.W1.T) * (output_h0 * (1 - output_h0)))
        else:
            self.gradient_W2.append((derivative_cross_entropy * derivative_sigmoid * output_h1).T)
            self.gradient_W1.append(derivative_cross_entropy * derivative_sigmoid * self.W2.T *self.relu_derivative(input_h1) * output_h0.T)
            self.gradient_W0.append(derivative_cross_entropy * derivative_sigmoid *self.relu_derivative(input_h1) * self.W2.T.dot(self.W1.T) * self.relu_derivative(input_h0) * x_input.T)
            self.gradient_b2.append(derivative_cross_entropy * derivative_sigmoid)
            self.gradient_b1.append(derivative_cross_entropy * derivative_sigmoid *self.W2.T * self.relu_derivative(input_h1))
            self.gradient_b0.append(derivative_cross_entropy * derivative_sigmoid *self.relu_derivative(input_h1) * self.W2.T.dot(self.W1.T) * self.relu_derivative(input_h0))

    def predict(self) -> float:
        self.results = np.empty([self.X_array_test.shape[0], 7])
        self.confusion_matrix = np.empty([2, 2])
        for i in range(0, self.X_array_test.shape[0]):
            x_t_input = self.X_array_test[[i]]
            y_t_input = self.Y_test[i]
            self.iteration_ff(x_t_input, i, y_t_input)
        self.results_data_frame = pd.DataFrame(self.results)
        self.results_data_frame.columns = ('X0', 'X1', 'Y true', 'Y pred.', 'Cost', 'Prediction', 'Correct?')
        accuracy = sum(self.results_data_frame.iloc[:, 6]) / self.X_array_test.shape[0]
        avg_cost = np.mean(self.results_data_frame.iloc[:, 4])
        self.confusion_matrix[0, 0] = sum((self.results_data_frame.iloc[:, 2] == 1) & (self.results_data_frame.iloc[:, 5] == 1))
        self.confusion_matrix[0, 1] = sum((self.results_data_frame.iloc[:, 2] == 1) & (self.results_data_frame.iloc[:, 5] == 0))
        self.confusion_matrix[1, 0] = sum((self.results_data_frame.iloc[:, 2] == 0) & (self.results_data_frame.iloc[:, 5] == 1))
        self.confusion_matrix[1, 1] = sum((self.results_data_frame.iloc[:, 2] == 0) & (self.results_data_frame.iloc[:, 5] == 0))
        self.confusion_matrix_data_frame = pd.DataFrame(self.confusion_matrix).astype(int)
        self.confusion_matrix_data_frame.columns = ('Predicted Class= 1','Predicted Class= 0')
        self.confusion_matrix_data_frame.index = ('True Class= 1', 'True Class= 0')
        dict1 = {1.0: "Yes", 0.0: "No"}
        self.results_data_frame.iloc[:, 6].replace(dict1, inplace=True)
        print(self.results_data_frame)
        print(f"\n ACCURACY: {accuracy * 100} %")
        print(f"\n AVERAGE COST FUNCTION: {round(avg_cost, 4)}")
        print(f"\n --------------- \n\nCONFUSION MATRIX \n")
        print(self.confusion_matrix_data_frame)
        return accuracy

    def iteration_ff(self, x_t_input, i, y_t_input):
        input_h0 = x_t_input.dot(self.final_W0) + self.final_bias0
        output_h0 = self.sigmoid(input_h0) if self.use_sigmoid else self.relu(input_h0)
        input_h1 = output_h0.dot(self.final_W1) + self.final_bias1
        output_h1 = self.sigmoid(input_h1) if self.use_sigmoid else self.relu(input_h1)
        input_sigmoid = output_h1.dot(self.final_W2) + self.final_bias2
        y_hat = self.sigmoid(input_sigmoid)
        
        self.results[i, 0] = round(x_t_input[0][0], 3)
        self.results[i, 1] = round(x_t_input[0][1], 3)
        self.results[i, 2] = y_t_input
        self.results[i, 3] = round(y_hat[0][0], 3)
        self.results[i, 4] = round(self.cross_entropy(y_hat, y_t_input)[0][0], 3)
        if y_hat[0][0] > 0.5:
            self.results[i, 5] = 1
        else:
            self.results[i, 5] = 0
        if self.results[i, 2] == self.results[i, 5]:
            self.results[i, 6] = 1
        else:
            self.results[i, 6] = 0
    
    def iteration_val(self, x_t_input, i, y_t_input): #this function computes the loss on the validation datapoints
        input_h0 = x_t_input.dot(self.W0) + self.bias0
        output_h0 = self.sigmoid(input_h0) if self.use_sigmoid else self.relu(input_h0)
        input_h1 = output_h0.dot(self.W1) + self.bias1
        output_h1 = self.sigmoid(input_h1) if self.use_sigmoid else self.relu(input_h1)
        input_sigmoid = output_h1.dot(self.W2) + self.bias2
        y_hat = self.sigmoid(input_sigmoid)
        if i<82:
            self.loss_function_val.append(self.cross_entropy(y_hat, y_t_input)[0][0])

# %%
HW3 = MLP(batch_size=10, alpha=0.05, epochs=200, no_neurons=10, use_sigmoid=False)

# %%
HW3.train()
# Out:
# AVG_LOSS_FUNCTION OF EPOCH 1 ON TRAINING SET: 1.2043628395156292
#
# AVG_LOSS_FUNCTION OF EPOCH 1 ON VALIDATION SET: 1.991595507882447
#
# AVG_LOSS_FUNCTION OF EPOCH 2 ON TRAINING SET: 0.7432229410096723
#
# AVG_LOSS_FUNCTION OF EPOCH 2 ON VALIDATION SET: 0.6966413802790484
#
# AVG_LOSS_FUNCTION OF EPOCH 3 ON TRAINING SET: 0.7226801100816115
#
# AVG_LOSS_FUNCTION OF EPOCH 3 ON VALIDATION SET: 0.6665485632281763
#
# AVG_LOSS_FUNCTION OF EPOCH 4 ON TRAINING SET: 0.7096630697176222
#
# AVG_LOSS_FUNCTION OF EPOCH 4 ON VALIDATION SET: 0.6515324623435496
#
# AVG_LOSS_FUNCTION OF EPOCH 5 ON TRAINING SET: 0.6985833834274693
#
# AVG_LOSS_FUNCTION OF EPOCH 5 ON VALIDATION SET: 0.6407590000796285
#
# AVG_LOSS_FUNCTION OF EPOCH 6 ON TRAINING SET: 0.6871968611075108
#
# AVG_LOSS_FUNCTION OF EPOCH 6 ON VALIDATION SET: 0.6306835425967168
#
# AVG_LOSS_FUNCTION OF EPOCH 7 ON TRAINING SET: 0.674595940298868
#
# AVG_LOSS_FUNCTION OF EPOCH 7 ON VALIDATION SET: 0.6196432455390736
#
# AVG_LOSS_FUNCTION OF EPOCH 8 ON TRAINING SET: 0.6583716183194299
#
# AVG_LOSS_FUNCTION OF EPOCH 8 ON VALIDATION SET: 0.6067739310273041
#
# AVG_LOSS_FUNCTION OF EPOCH 9 ON TRAINING SET: 0.63566711570812
#
# AVG_LOSS_FUNCTION OF EPOCH 9 ON VALIDATION SET: 0.5878671690002519
#
# AVG_LOSS_FUNCTION OF EPOCH 10 ON TRAINING SET: 0.6135149524129984
#
# AVG_LOSS_FUNCTION OF EPOCH 10 ON VALIDATION SET: 0.5642928700326261
#
# AVG_LOSS_FUNCTION OF EPOCH 11 ON TRAINING SET: 0.5933313193429364
#
# AVG_LOSS_FUNCTION OF EPOCH 11 ON VALIDATION SET: 0.5449835550694836
#
# AVG_LOSS_FUNCTION OF EPOCH 12 ON TRAINING SET: 0.5707075269278447
#
# AVG_LOSS_FUNCTION OF EPOCH 12 ON VALIDATION SET: 0.5249601964122919
#
# AVG_LOSS_FUNCTION OF EPOCH 13 ON TRAINING SET: 0.5435469101968138
#
# AVG_LOSS_FUNCTION OF EPOCH 13 ON VALIDATION SET: 0.5002699113869039
#
# AVG_LOSS_FUNCTION OF EPOCH 14 ON TRAINING SET: 0.5157092156664045
#
# AVG_LOSS_FUNCTION OF EPOCH 14 ON VALIDATION SET: 0.47325334610781744
#
# AVG_LOSS_FUNCTION OF EPOCH 15 ON TRAINING SET: 0.4891165229070061
#
# AVG_LOSS_FUNCTION OF EPOCH 15 ON VALIDATION SET: 0.44714769043843244
#
# AVG_LOSS_FUNCTION OF EPOCH 16 ON TRAINING SET: 0.46194964309014014
#
# AVG_LOSS_FUNCTION OF EPOCH 16 ON VALIDATION SET: 0.4211412582103218
#
# AVG_LOSS_FUNCTION OF EPOCH 17 ON TRAINING SET: 0.43358022787428274
#
# AVG_LOSS_FUNCTION OF EPOCH 17 ON VALIDATION SET: 0.3939049919137301
#
# AVG_LOSS_FUNCTION OF EPOCH 18 ON TRAINING SET: 0.404571279391674
#
# AVG_LOSS_FUNCTION OF EPOCH 18 ON VALIDATION SET: 0.36650531035497186
#
# AVG_LOSS_FUNCTION OF EPOCH 19 ON TRAINING SET: 0.3755918766910319
#
# AVG_LOSS_FUNCTION OF EPOCH 19 ON VALIDATION SET: 0.339174633265022
#
# AVG_LOSS_FUNCTION OF EPOCH 20 ON TRAINING SET: 0.34673880603847196
#
# AVG_LOSS_FUNCTION OF EPOCH 20 ON VALIDATION SET: 0.31266995375257856
#
# AVG_LOSS_FUNCTION OF EPOCH 21 ON TRAINING SET: 0.3204788206111948
#
# AVG_LOSS_FUNCTION OF EPOCH 21 ON VALIDATION SET: 0.28733928894059035
#
# AVG_LOSS_FUNCTION OF EPOCH 22 ON TRAINING SET: 0.2974121450480288
#
# AVG_LOSS_FUNCTION OF EPOCH 22 ON VALIDATION SET: 0.2650243957159461
#
# AVG_LOSS_FUNCTION OF EPOCH 23 ON TRAINING SET: 0.2780441441561886
#
# AVG_LOSS_FUNCTION OF EPOCH 23 ON VALIDATION SET: 0.24567998832865262
#
# AVG_LOSS_FUNCTION OF EPOCH 24 ON TRAINING SET: 0.261188692262609
#
# AVG_LOSS_FUNCTION OF EPOCH 24 ON VALIDATION SET: 0.22917592628362227
#
# AVG_LOSS_FUNCTION OF EPOCH 25 ON TRAINING SET: 0.24713861607808613
#
# AVG_LOSS_FUNCTION OF EPOCH 25 ON VALIDATION SET: 0.21504460450521473
#
# AVG_LOSS_FUNCTION OF EPOCH 26 ON TRAINING SET: 0.23671719269708638
#
# AVG_LOSS_FUNCTION OF EPOCH 26 ON VALIDATION SET: 0.20333983783234655
#
# AVG_LOSS_FUNCTION OF EPOCH 27 ON TRAINING SET: 0.22643363543535328
#
# AVG_LOSS_FUNCTION OF EPOCH 27 ON VALIDATION SET: 0.19393467077572135
#
# AVG_LOSS_FUNCTION OF EPOCH 28 ON TRAINING SET: 0.2178679833312253
#
# AVG_LOSS_FUNCTION OF EPOCH 28 ON VALIDATION SET: 0.18596844149426006
#
# AVG_LOSS_FUNCTION OF EPOCH 29 ON TRAINING SET: 0.2108914408238296
#
# AVG_LOSS_FUNCTION OF EPOCH 29 ON VALIDATION SET: 0.17950734650941336
#
# AVG_LOSS_FUNCTION OF EPOCH 30 ON TRAINING SET: 0.20505760635712797
#
# AVG_LOSS_FUNCTION OF EPOCH 30 ON VALIDATION SET: 0.17399739192752528
#
# AVG_LOSS_FUNCTION OF EPOCH 31 ON TRAINING SET: 0.2005400234104181
#
# AVG_LOSS_FUNCTION OF EPOCH 31 ON VALIDATION SET: 0.1693245378360579
#
# AVG_LOSS_FUNCTION OF EPOCH 32 ON TRAINING SET: 0.19680076194849783
#
# AVG_LOSS_FUNCTION OF EPOCH 32 ON VALIDATION SET: 0.17139520586555226
#
# AVG_LOSS_FUNCTION OF EPOCH 33 ON TRAINING SET: 0.1928734820386855
#
# AVG_LOSS_FUNCTION OF EPOCH 33 ON VALIDATION SET: 0.1689771537827223
#
# AVG_LOSS_FUNCTION OF EPOCH 34 ON TRAINING SET: 0.18977901452926207
#
# AVG_LOSS_FUNCTION OF EPOCH 34 ON VALIDATION SET: 0.1675025916997288
#
# AVG_LOSS_FUNCTION OF EPOCH 35 ON TRAINING SET: 0.1871048466568934
#
# AVG_LOSS_FUNCTION OF EPOCH 35 ON VALIDATION SET: 0.16617880068440594
#
# AVG_LOSS_FUNCTION OF EPOCH 36 ON TRAINING SET: 0.18494928222139195
#
# AVG_LOSS_FUNCTION OF EPOCH 36 ON VALIDATION SET: 0.1654633073866266
#
# AVG_LOSS_FUNCTION OF EPOCH 37 ON TRAINING SET: 0.18298028511303716
#
# AVG_LOSS_FUNCTION OF EPOCH 37 ON VALIDATION SET: 0.1649132015335394
#
# AVG_LOSS_FUNCTION OF EPOCH 38 ON TRAINING SET: 0.18141639249022243
#
# AVG_LOSS_FUNCTION OF EPOCH 38 ON VALIDATION SET: 0.1645861147126345
#
# AVG_LOSS_FUNCTION OF EPOCH 39 ON TRAINING SET: 0.18000469149748244
#
# AVG_LOSS_FUNCTION OF EPOCH 39 ON VALIDATION SET: 0.16448414179367582
#
# AVG_LOSS_FUNCTION OF EPOCH 40 ON TRAINING SET: 0.1789173847744036
#
# AVG_LOSS_FUNCTION OF EPOCH 40 ON VALIDATION SET: 0.16431301396531278
#
# AVG_LOSS_FUNCTION OF EPOCH 41 ON TRAINING SET: 0.1779406139378756
#
# AVG_LOSS_FUNCTION OF EPOCH 41 ON VALIDATION SET: 0.16440821541070105
#
# AVG_LOSS_FUNCTION OF EPOCH 42 ON TRAINING SET: 0.17720044124825662
#
# AVG_LOSS_FUNCTION OF EPOCH 42 ON VALIDATION SET: 0.16430580885103974
#
# AVG_LOSS_FUNCTION OF EPOCH 43 ON TRAINING SET: 0.1765571106282127
#
# AVG_LOSS_FUNCTION OF EPOCH 43 ON VALIDATION SET: 0.1645164853285411
#
# AVG_LOSS_FUNCTION OF EPOCH 44 ON TRAINING SET: 0.1758929866990022
#
# AVG_LOSS_FUNCTION OF EPOCH 44 ON VALIDATION SET: 0.1649931399150664
#
# AVG_LOSS_FUNCTION OF EPOCH 45 ON TRAINING SET: 0.17537302495603768
#
# AVG_LOSS_FUNCTION OF EPOCH 45 ON VALIDATION SET: 0.1651080438216835
#
# AVG_LOSS_FUNCTION OF EPOCH 46 ON TRAINING SET: 0.17481298851520738
#
# AVG_LOSS_FUNCTION OF EPOCH 46 ON VALIDATION SET: 0.16567868466368688
#
# AVG_LOSS_FUNCTION OF EPOCH 47 ON TRAINING SET: 0.17460803379182996
#
# AVG_LOSS_FUNCTION OF EPOCH 47 ON VALIDATION SET: 0.16589353874054338
#
# AVG_LOSS_FUNCTION OF EPOCH 48 ON TRAINING SET: 0.17427956756489968
#
# AVG_LOSS_FUNCTION OF EPOCH 48 ON VALIDATION SET: 0.16635284107224005
#
# AVG_LOSS_FUNCTION OF EPOCH 49 ON TRAINING SET: 0.17403671616410887
#
# AVG_LOSS_FUNCTION OF EPOCH 49 ON VALIDATION SET: 0.16674871353226195
#
# AVG_LOSS_FUNCTION OF EPOCH 50 ON TRAINING SET: 0.17384854336648448
#
# AVG_LOSS_FUNCTION OF EPOCH 50 ON VALIDATION SET: 0.1672341695899437
#
# AVG_LOSS_FUNCTION OF EPOCH 51 ON TRAINING SET: 0.17339879844359482
#
# AVG_LOSS_FUNCTION OF EPOCH 51 ON VALIDATION SET: 0.16770921138842168
#
# AVG_LOSS_FUNCTION OF EPOCH 52 ON TRAINING SET: 0.17335827519031313
#
# AVG_LOSS_FUNCTION OF EPOCH 52 ON VALIDATION SET: 0.16817957176830106
#
# AVG_LOSS_FUNCTION OF EPOCH 53 ON TRAINING SET: 0.1731096925910981
#
# AVG_LOSS_FUNCTION OF EPOCH 53 ON VALIDATION SET: 0.16856540567777756
#
# AVG_LOSS_FUNCTION OF EPOCH 54 ON TRAINING SET: 0.17302077131599738
#
# AVG_LOSS_FUNCTION OF EPOCH 54 ON VALIDATION SET: 0.16894252356493952
#
# AVG_LOSS_FUNCTION OF EPOCH 55 ON TRAINING SET: 0.17283305747694572
#
# AVG_LOSS_FUNCTION OF EPOCH 55 ON VALIDATION SET: 0.16934163453349513
#
# AVG_LOSS_FUNCTION OF EPOCH 56 ON TRAINING SET: 0.17271288444484847
#
# AVG_LOSS_FUNCTION OF EPOCH 56 ON VALIDATION SET: 0.1699932760081205
#
# AVG_LOSS_FUNCTION OF EPOCH 57 ON TRAINING SET: 0.1725927722088237
#
# AVG_LOSS_FUNCTION OF EPOCH 57 ON VALIDATION SET: 0.17017453419327497
#
# AVG_LOSS_FUNCTION OF EPOCH 58 ON TRAINING SET: 0.17252757544098196
#
# AVG_LOSS_FUNCTION OF EPOCH 58 ON VALIDATION SET: 0.1708150450128846
#
# AVG_LOSS_FUNCTION OF EPOCH 59 ON TRAINING SET: 0.17246947656058337
#
# AVG_LOSS_FUNCTION OF EPOCH 59 ON VALIDATION SET: 0.17101782708635893
#
# AVG_LOSS_FUNCTION OF EPOCH 60 ON TRAINING SET: 0.1723238746601924
#
# AVG_LOSS_FUNCTION OF EPOCH 60 ON VALIDATION SET: 0.17133723280392055
# AVG_LOSS_FUNCTION OF EPOCH 61 ON TRAINING SET: 0.17220245208310606
#
# AVG_LOSS_FUNCTION OF EPOCH 61 ON VALIDATION SET: 0.17200440899724262
#
# AVG_LOSS_FUNCTION OF EPOCH 62 ON TRAINING SET: 0.17219801408338428
#
# AVG_LOSS_FUNCTION OF EPOCH 62 ON VALIDATION SET: 0.1722006662090062
#
# AVG_LOSS_FUNCTION OF EPOCH 63 ON TRAINING SET: 0.172070407381415
#
# AVG_LOSS_FUNCTION OF EPOCH 63 ON VALIDATION SET: 0.17246950462602847
#
# AVG_LOSS_FUNCTION OF EPOCH 64 ON TRAINING SET: 0.17196929761303645
#
# AVG_LOSS_FUNCTION OF EPOCH 64 ON VALIDATION SET: 0.17279788251327335
#
# AVG_LOSS_FUNCTION OF EPOCH 65 ON TRAINING SET: 0.17194451819397066
#
# AVG_LOSS_FUNCTION OF EPOCH 65 ON VALIDATION SET: 0.17314113001101902
#
# AVG_LOSS_FUNCTION OF EPOCH 66 ON TRAINING SET: 0.17176318815877406
#
# AVG_LOSS_FUNCTION OF EPOCH 66 ON VALIDATION SET: 0.17368940115518394
#
# AVG_LOSS_FUNCTION OF EPOCH 67 ON TRAINING SET: 0.17172419114988358
#
# AVG_LOSS_FUNCTION OF EPOCH 67 ON VALIDATION SET: 0.17377459907219042
#
# AVG_LOSS_FUNCTION OF EPOCH 68 ON TRAINING SET: 0.1715800074876303
#
# AVG_LOSS_FUNCTION OF EPOCH 68 ON VALIDATION SET: 0.17405192532800712
#
# AVG_LOSS_FUNCTION OF EPOCH 69 ON TRAINING SET: 0.17154039319484393
#
# AVG_LOSS_FUNCTION OF EPOCH 69 ON VALIDATION SET: 0.17431452600937736
#
# AVG_LOSS_FUNCTION OF EPOCH 70 ON TRAINING SET: 0.1713276852820318
#
# AVG_LOSS_FUNCTION OF EPOCH 70 ON VALIDATION SET: 0.1748068394460066
#
# AVG_LOSS_FUNCTION OF EPOCH 71 ON TRAINING SET: 0.17128459402656893
#
# AVG_LOSS_FUNCTION OF EPOCH 71 ON VALIDATION SET: 0.17483840208052356
#
# AVG_LOSS_FUNCTION OF EPOCH 72 ON TRAINING SET: 0.17111768856964918
#
# AVG_LOSS_FUNCTION OF EPOCH 72 ON VALIDATION SET: 0.17503479430935961
#
# AVG_LOSS_FUNCTION OF EPOCH 73 ON TRAINING SET: 0.1710061056827456
#
# AVG_LOSS_FUNCTION OF EPOCH 73 ON VALIDATION SET: 0.17553310318565113
#
# AVG_LOSS_FUNCTION OF EPOCH 74 ON TRAINING SET: 0.17092201467155496
#
# AVG_LOSS_FUNCTION OF EPOCH 74 ON VALIDATION SET: 0.17547820533355443
#
# AVG_LOSS_FUNCTION OF EPOCH 75 ON TRAINING SET: 0.17078865956327127
#
# AVG_LOSS_FUNCTION OF EPOCH 75 ON VALIDATION SET: 0.1755700327890884
#
# AVG_LOSS_FUNCTION OF EPOCH 76 ON TRAINING SET: 0.17057705639192253
#
# AVG_LOSS_FUNCTION OF EPOCH 76 ON VALIDATION SET: 0.17604755336126113
#
# AVG_LOSS_FUNCTION OF EPOCH 77 ON TRAINING SET: 0.170517204703176
#
# AVG_LOSS_FUNCTION OF EPOCH 77 ON VALIDATION SET: 0.1759287278033382
#
# AVG_LOSS_FUNCTION OF EPOCH 78 ON TRAINING SET: 0.17037367522521707
#
# AVG_LOSS_FUNCTION OF EPOCH 78 ON VALIDATION SET: 0.17605404735101762
#
# AVG_LOSS_FUNCTION OF EPOCH 79 ON TRAINING SET: 0.17017903223228223
#
# AVG_LOSS_FUNCTION OF EPOCH 79 ON VALIDATION SET: 0.17642387319273511
#
# AVG_LOSS_FUNCTION OF EPOCH 80 ON TRAINING SET: 0.1700766901481311
#
# AVG_LOSS_FUNCTION OF EPOCH 80 ON VALIDATION SET: 0.17629392470520142
#
# AVG_LOSS_FUNCTION OF EPOCH 81 ON TRAINING SET: 0.16983624779692202
#
# AVG_LOSS_FUNCTION OF EPOCH 81 ON VALIDATION SET: 0.1766700698060842
#
# AVG_LOSS_FUNCTION OF EPOCH 82 ON TRAINING SET: 0.1697935634142752
#
# AVG_LOSS_FUNCTION OF EPOCH 82 ON VALIDATION SET: 0.17651294349146485
#
# AVG_LOSS_FUNCTION OF EPOCH 83 ON TRAINING SET: 0.1697507093246635
#
# AVG_LOSS_FUNCTION OF EPOCH 83 ON VALIDATION SET: 0.17651783632724719
#
# AVG_LOSS_FUNCTION OF EPOCH 84 ON TRAINING SET: 0.16947500481587718
#
# AVG_LOSS_FUNCTION OF EPOCH 84 ON VALIDATION SET: 0.17657454341552414
#
# AVG_LOSS_FUNCTION OF EPOCH 85 ON TRAINING SET: 0.16943672123487616
#
# AVG_LOSS_FUNCTION OF EPOCH 85 ON VALIDATION SET: 0.1769289572112952
#
# AVG_LOSS_FUNCTION OF EPOCH 86 ON TRAINING SET: 0.16917101953237743
#
# AVG_LOSS_FUNCTION OF EPOCH 86 ON VALIDATION SET: 0.17666504670198227
#
# AVG_LOSS_FUNCTION OF EPOCH 87 ON TRAINING SET: 0.16913443821245952
#
# AVG_LOSS_FUNCTION OF EPOCH 87 ON VALIDATION SET: 0.1769862896507797
#
# AVG_LOSS_FUNCTION OF EPOCH 88 ON TRAINING SET: 0.1689912061571542
#
# AVG_LOSS_FUNCTION OF EPOCH 88 ON VALIDATION SET: 0.1767197642699586
#
# AVG_LOSS_FUNCTION OF EPOCH 89 ON TRAINING SET: 0.16810371828493587
#
# AVG_LOSS_FUNCTION OF EPOCH 89 ON VALIDATION SET: 0.17678861008930036
#
# AVG_LOSS_FUNCTION OF EPOCH 90 ON TRAINING SET: 0.1678631442343298
#
# AVG_LOSS_FUNCTION OF EPOCH 90 ON VALIDATION SET: 0.17640164573071324
#
# AVG_LOSS_FUNCTION OF EPOCH 91 ON TRAINING SET: 0.16832546839100557
#
# AVG_LOSS_FUNCTION OF EPOCH 91 ON VALIDATION SET: 0.17622760006731503
#
# AVG_LOSS_FUNCTION OF EPOCH 92 ON TRAINING SET: 0.1681162921970509
#
# AVG_LOSS_FUNCTION OF EPOCH 92 ON VALIDATION SET: 0.17650142999575785
#
# AVG_LOSS_FUNCTION OF EPOCH 93 ON TRAINING SET: 0.16794229418130013
#
# AVG_LOSS_FUNCTION OF EPOCH 93 ON VALIDATION SET: 0.17666634686715332
#
# AVG_LOSS_FUNCTION OF EPOCH 94 ON TRAINING SET: 0.16770602791490202
#
# AVG_LOSS_FUNCTION OF EPOCH 94 ON VALIDATION SET: 0.17692378994324098
#
# AVG_LOSS_FUNCTION OF EPOCH 95 ON TRAINING SET: 0.16767338111379748
#
# AVG_LOSS_FUNCTION OF EPOCH 95 ON VALIDATION SET: 0.17718259049545063
#
# AVG_LOSS_FUNCTION OF EPOCH 96 ON TRAINING SET: 0.16756364567154786
#
# AVG_LOSS_FUNCTION OF EPOCH 96 ON VALIDATION SET: 0.17732982248148882
#
# AVG_LOSS_FUNCTION OF EPOCH 97 ON TRAINING SET: 0.16740173573171616
#
# AVG_LOSS_FUNCTION OF EPOCH 97 ON VALIDATION SET: 0.17734958487364386
#
# AVG_LOSS_FUNCTION OF EPOCH 98 ON TRAINING SET: 0.16726875157181345
#
# AVG_LOSS_FUNCTION OF EPOCH 98 ON VALIDATION SET: 0.17744675075397803
#
# AVG_LOSS_FUNCTION OF EPOCH 99 ON TRAINING SET: 0.1671270682176639
#
# AVG_LOSS_FUNCTION OF EPOCH 99 ON VALIDATION SET: 0.1774680824612628
#
# AVG_LOSS_FUNCTION OF EPOCH 100 ON TRAINING SET: 0.16703914645162207
#
# AVG_LOSS_FUNCTION OF EPOCH 100 ON VALIDATION SET: 0.17749437986227037
#
# AVG_LOSS_FUNCTION OF EPOCH 101 ON TRAINING SET: 0.16680598206787772
#
# AVG_LOSS_FUNCTION OF EPOCH 101 ON VALIDATION SET: 0.17752944148315192
#
# AVG_LOSS_FUNCTION OF EPOCH 102 ON TRAINING SET: 0.16665679723101667
#
# AVG_LOSS_FUNCTION OF EPOCH 102 ON VALIDATION SET: 0.1775037085148599
#
# AVG_LOSS_FUNCTION OF EPOCH 103 ON TRAINING SET: 0.16654231991947785
#
# AVG_LOSS_FUNCTION OF EPOCH 103 ON VALIDATION SET: 0.17750302750947436
#
# AVG_LOSS_FUNCTION OF EPOCH 104 ON TRAINING SET: 0.16637107736290244
#
# AVG_LOSS_FUNCTION OF EPOCH 104 ON VALIDATION SET: 0.17748080876066416
#
# AVG_LOSS_FUNCTION OF EPOCH 105 ON TRAINING SET: 0.16623283330443306
#
# AVG_LOSS_FUNCTION OF EPOCH 105 ON VALIDATION SET: 0.17749198118918605
#
# AVG_LOSS_FUNCTION OF EPOCH 106 ON TRAINING SET: 0.16605591694588764
#
# AVG_LOSS_FUNCTION OF EPOCH 106 ON VALIDATION SET: 0.17750311756176473
#
# AVG_LOSS_FUNCTION OF EPOCH 107 ON TRAINING SET: 0.16594121508746768
#
# AVG_LOSS_FUNCTION OF EPOCH 107 ON VALIDATION SET: 0.17747884577168394
#
# AVG_LOSS_FUNCTION OF EPOCH 108 ON TRAINING SET: 0.16576415114714085
#
# AVG_LOSS_FUNCTION OF EPOCH 108 ON VALIDATION SET: 0.17743698563134194
#
# AVG_LOSS_FUNCTION OF EPOCH 109 ON TRAINING SET: 0.16560007738257188
#
# AVG_LOSS_FUNCTION OF EPOCH 109 ON VALIDATION SET: 0.17744449850289276
#
# AVG_LOSS_FUNCTION OF EPOCH 110 ON TRAINING SET: 0.16547108859646992
#
# AVG_LOSS_FUNCTION OF EPOCH 110 ON VALIDATION SET: 0.1774148874890975
#
# AVG_LOSS_FUNCTION OF EPOCH 111 ON TRAINING SET: 0.16529184419802898
#
# AVG_LOSS_FUNCTION OF EPOCH 111 ON VALIDATION SET: 0.17741668343335887
#
# AVG_LOSS_FUNCTION OF EPOCH 112 ON TRAINING SET: 0.1651456456857538
#
# AVG_LOSS_FUNCTION OF EPOCH 112 ON VALIDATION SET: 0.17738362676114622
#
# AVG_LOSS_FUNCTION OF EPOCH 113 ON TRAINING SET: 0.16502508176080505
#
# AVG_LOSS_FUNCTION OF EPOCH 113 ON VALIDATION SET: 0.17753751522738662
#
# AVG_LOSS_FUNCTION OF EPOCH 114 ON TRAINING SET: 0.16484753831900675
#
# AVG_LOSS_FUNCTION OF EPOCH 114 ON VALIDATION SET: 0.1770786433775936
#
# AVG_LOSS_FUNCTION OF EPOCH 115 ON TRAINING SET: 0.16468870128744578
#
# AVG_LOSS_FUNCTION OF EPOCH 115 ON VALIDATION SET: 0.1770628408234757
#
# AVG_LOSS_FUNCTION OF EPOCH 116 ON TRAINING SET: 0.1645436889990548
#
# AVG_LOSS_FUNCTION OF EPOCH 116 ON VALIDATION SET: 0.17705678448108483
#
# AVG_LOSS_FUNCTION OF EPOCH 117 ON TRAINING SET: 0.1643898667013294
#
# AVG_LOSS_FUNCTION OF EPOCH 117 ON VALIDATION SET: 0.17703403020783612
#
# AVG_LOSS_FUNCTION OF EPOCH 118 ON TRAINING SET: 0.1642392041604368
#
# AVG_LOSS_FUNCTION OF EPOCH 118 ON VALIDATION SET: 0.17700772566129513
#
# AVG_LOSS_FUNCTION OF EPOCH 119 ON TRAINING SET: 0.16413010831163372
#
# AVG_LOSS_FUNCTION OF EPOCH 119 ON VALIDATION SET: 0.17716049562038572
#
# AVG_LOSS_FUNCTION OF EPOCH 120 ON TRAINING SET: 0.1639385379313529
#
# AVG_LOSS_FUNCTION OF EPOCH 120 ON VALIDATION SET: 0.17672789283470813
# AVG_LOSS_FUNCTION OF EPOCH 121 ON TRAINING SET: 0.16378501599307915
#
# AVG_LOSS_FUNCTION OF EPOCH 121 ON VALIDATION SET: 0.17669984184903645
#
# AVG_LOSS_FUNCTION OF EPOCH 122 ON TRAINING SET: 0.16363432510541545
#
# AVG_LOSS_FUNCTION OF EPOCH 122 ON VALIDATION SET: 0.17668464233084397
#
# AVG_LOSS_FUNCTION OF EPOCH 123 ON TRAINING SET: 0.1634872174300828
#
# AVG_LOSS_FUNCTION OF EPOCH 123 ON VALIDATION SET: 0.17685395813117666
#
# AVG_LOSS_FUNCTION OF EPOCH 124 ON TRAINING SET: 0.16333631744909352
#
# AVG_LOSS_FUNCTION OF EPOCH 124 ON VALIDATION SET: 0.1764399133530821
#
# AVG_LOSS_FUNCTION OF EPOCH 125 ON TRAINING SET: 0.16318414815736337
#
# AVG_LOSS_FUNCTION OF EPOCH 125 ON VALIDATION SET: 0.1764197903422113
#
# AVG_LOSS_FUNCTION OF EPOCH 126 ON TRAINING SET: 0.16303386964928482
#
# AVG_LOSS_FUNCTION OF EPOCH 126 ON VALIDATION SET: 0.17641669731755616
#
# AVG_LOSS_FUNCTION OF EPOCH 127 ON TRAINING SET: 0.16290442361838078
#
# AVG_LOSS_FUNCTION OF EPOCH 127 ON VALIDATION SET: 0.1766036210859367
#
# AVG_LOSS_FUNCTION OF EPOCH 128 ON TRAINING SET: 0.1627510672693833
#
# AVG_LOSS_FUNCTION OF EPOCH 128 ON VALIDATION SET: 0.17613675843363008
#
# AVG_LOSS_FUNCTION OF EPOCH 129 ON TRAINING SET: 0.16260390459813673
#
# AVG_LOSS_FUNCTION OF EPOCH 129 ON VALIDATION SET: 0.17615000466434835
#
# AVG_LOSS_FUNCTION OF EPOCH 130 ON TRAINING SET: 0.1624566628012724
#
# AVG_LOSS_FUNCTION OF EPOCH 130 ON VALIDATION SET: 0.1761590851142655
#
# AVG_LOSS_FUNCTION OF EPOCH 131 ON TRAINING SET: 0.16231757040306397
#
# AVG_LOSS_FUNCTION OF EPOCH 131 ON VALIDATION SET: 0.17638512228147712
#
# AVG_LOSS_FUNCTION OF EPOCH 132 ON TRAINING SET: 0.16217124663263638
#
# AVG_LOSS_FUNCTION OF EPOCH 132 ON VALIDATION SET: 0.17595270829777995
#
# AVG_LOSS_FUNCTION OF EPOCH 133 ON TRAINING SET: 0.16202187962624848
#
# AVG_LOSS_FUNCTION OF EPOCH 133 ON VALIDATION SET: 0.17596384937538245
#
# AVG_LOSS_FUNCTION OF EPOCH 134 ON TRAINING SET: 0.16189165541283504
#
# AVG_LOSS_FUNCTION OF EPOCH 134 ON VALIDATION SET: 0.1761866650424579
#
# AVG_LOSS_FUNCTION OF EPOCH 135 ON TRAINING SET: 0.16174505791451604
#
# AVG_LOSS_FUNCTION OF EPOCH 135 ON VALIDATION SET: 0.17578109920109947
#
# AVG_LOSS_FUNCTION OF EPOCH 136 ON TRAINING SET: 0.16160595985126927
#
# AVG_LOSS_FUNCTION OF EPOCH 136 ON VALIDATION SET: 0.17578033075253116
#
# AVG_LOSS_FUNCTION OF EPOCH 137 ON TRAINING SET: 0.16147612294986288
#
# AVG_LOSS_FUNCTION OF EPOCH 137 ON VALIDATION SET: 0.17602153478880045
#
# AVG_LOSS_FUNCTION OF EPOCH 138 ON TRAINING SET: 0.16133259102049685
#
# AVG_LOSS_FUNCTION OF EPOCH 138 ON VALIDATION SET: 0.17561139120536817
#
# AVG_LOSS_FUNCTION OF EPOCH 139 ON TRAINING SET: 0.16119850541800035
#
# AVG_LOSS_FUNCTION OF EPOCH 139 ON VALIDATION SET: 0.17561626662593144
#
# AVG_LOSS_FUNCTION OF EPOCH 140 ON TRAINING SET: 0.16107090321516865
#
# AVG_LOSS_FUNCTION OF EPOCH 140 ON VALIDATION SET: 0.17588048698813805
#
# AVG_LOSS_FUNCTION OF EPOCH 141 ON TRAINING SET: 0.160928395677478
#
# AVG_LOSS_FUNCTION OF EPOCH 141 ON VALIDATION SET: 0.1754583238113647
#
# AVG_LOSS_FUNCTION OF EPOCH 142 ON TRAINING SET: 0.16079867489055824
#
# AVG_LOSS_FUNCTION OF EPOCH 142 ON VALIDATION SET: 0.17547340737664985
#
# AVG_LOSS_FUNCTION OF EPOCH 143 ON TRAINING SET: 0.1606655696943585
#
# AVG_LOSS_FUNCTION OF EPOCH 143 ON VALIDATION SET: 0.17572712448650066
#
# AVG_LOSS_FUNCTION OF EPOCH 144 ON TRAINING SET: 0.16055282778479438
#
# AVG_LOSS_FUNCTION OF EPOCH 144 ON VALIDATION SET: 0.17530665888734454
#
# AVG_LOSS_FUNCTION OF EPOCH 145 ON TRAINING SET: 0.16040498390173413
#
# AVG_LOSS_FUNCTION OF EPOCH 145 ON VALIDATION SET: 0.17534418774086258
#
# AVG_LOSS_FUNCTION OF EPOCH 146 ON TRAINING SET: 0.16028954132683507
#
# AVG_LOSS_FUNCTION OF EPOCH 146 ON VALIDATION SET: 0.17562345383460382
#
# AVG_LOSS_FUNCTION OF EPOCH 147 ON TRAINING SET: 0.16014789667692886
#
# AVG_LOSS_FUNCTION OF EPOCH 147 ON VALIDATION SET: 0.17520595245247075
#
# AVG_LOSS_FUNCTION OF EPOCH 148 ON TRAINING SET: 0.16001733574659122
#
# AVG_LOSS_FUNCTION OF EPOCH 148 ON VALIDATION SET: 0.17545457829128097
#
# AVG_LOSS_FUNCTION OF EPOCH 149 ON TRAINING SET: 0.15991472397529294
#
# AVG_LOSS_FUNCTION OF EPOCH 149 ON VALIDATION SET: 0.17504693057506446
#
# AVG_LOSS_FUNCTION OF EPOCH 150 ON TRAINING SET: 0.15976933919087424
#
# AVG_LOSS_FUNCTION OF EPOCH 150 ON VALIDATION SET: 0.1750981465086588
#
# AVG_LOSS_FUNCTION OF EPOCH 151 ON TRAINING SET: 0.15964933163438771
#
# AVG_LOSS_FUNCTION OF EPOCH 151 ON VALIDATION SET: 0.17537673664967243
#
# AVG_LOSS_FUNCTION OF EPOCH 152 ON TRAINING SET: 0.159544620575512
#
# AVG_LOSS_FUNCTION OF EPOCH 152 ON VALIDATION SET: 0.17494943941192792
#
# AVG_LOSS_FUNCTION OF EPOCH 153 ON TRAINING SET: 0.15939857994741702
#
# AVG_LOSS_FUNCTION OF EPOCH 153 ON VALIDATION SET: 0.1752423072505993
#
# AVG_LOSS_FUNCTION OF EPOCH 154 ON TRAINING SET: 0.15930402888859535
#
# AVG_LOSS_FUNCTION OF EPOCH 154 ON VALIDATION SET: 0.17482673260125794
#
# AVG_LOSS_FUNCTION OF EPOCH 155 ON TRAINING SET: 0.1591611210653492
#
# AVG_LOSS_FUNCTION OF EPOCH 155 ON VALIDATION SET: 0.1748981551058427
#
# AVG_LOSS_FUNCTION OF EPOCH 156 ON TRAINING SET: 0.15906376960502916
#
# AVG_LOSS_FUNCTION OF EPOCH 156 ON VALIDATION SET: 0.17520251796976333
#
# AVG_LOSS_FUNCTION OF EPOCH 157 ON TRAINING SET: 0.15893073648722153
#
# AVG_LOSS_FUNCTION OF EPOCH 157 ON VALIDATION SET: 0.17479082820187855
#
# AVG_LOSS_FUNCTION OF EPOCH 158 ON TRAINING SET: 0.15881193565636315
#
# AVG_LOSS_FUNCTION OF EPOCH 158 ON VALIDATION SET: 0.1750835766751746
#
# AVG_LOSS_FUNCTION OF EPOCH 159 ON TRAINING SET: 0.15871519456496633
#
# AVG_LOSS_FUNCTION OF EPOCH 159 ON VALIDATION SET: 0.17467118569709628
#
# AVG_LOSS_FUNCTION OF EPOCH 160 ON TRAINING SET: 0.1585742006053957
#
# AVG_LOSS_FUNCTION OF EPOCH 160 ON VALIDATION SET: 0.17500148981213523
#
# AVG_LOSS_FUNCTION OF EPOCH 161 ON TRAINING SET: 0.1584864378175314
#
# AVG_LOSS_FUNCTION OF EPOCH 161 ON VALIDATION SET: 0.17458881188417344
#
# AVG_LOSS_FUNCTION OF EPOCH 162 ON TRAINING SET: 0.15835818181530859
#
# AVG_LOSS_FUNCTION OF EPOCH 162 ON VALIDATION SET: 0.1746494641691963
#
# AVG_LOSS_FUNCTION OF EPOCH 163 ON TRAINING SET: 0.15825887704318964
#
# AVG_LOSS_FUNCTION OF EPOCH 163 ON VALIDATION SET: 0.17498238610103092
#
# AVG_LOSS_FUNCTION OF EPOCH 164 ON TRAINING SET: 0.15813900845997383
#
# AVG_LOSS_FUNCTION OF EPOCH 164 ON VALIDATION SET: 0.17454557855950878
#
# AVG_LOSS_FUNCTION OF EPOCH 165 ON TRAINING SET: 0.15803503989470544
#
# AVG_LOSS_FUNCTION OF EPOCH 165 ON VALIDATION SET: 0.17488017947068923
#
# AVG_LOSS_FUNCTION OF EPOCH 166 ON TRAINING SET: 0.1579161446682798
#
# AVG_LOSS_FUNCTION OF EPOCH 166 ON VALIDATION SET: 0.1744647273932342
#
# AVG_LOSS_FUNCTION OF EPOCH 167 ON TRAINING SET: 0.15781644218201388
#
# AVG_LOSS_FUNCTION OF EPOCH 167 ON VALIDATION SET: 0.17477631035797908
#
# AVG_LOSS_FUNCTION OF EPOCH 168 ON TRAINING SET: 0.1576963906127819
#
# AVG_LOSS_FUNCTION OF EPOCH 168 ON VALIDATION SET: 0.1743953761030196
#
# AVG_LOSS_FUNCTION OF EPOCH 169 ON TRAINING SET: 0.15759978069887828
#
# AVG_LOSS_FUNCTION OF EPOCH 169 ON VALIDATION SET: 0.17472263036218375
#
# AVG_LOSS_FUNCTION OF EPOCH 170 ON TRAINING SET: 0.1574858825105617
#
# AVG_LOSS_FUNCTION OF EPOCH 170 ON VALIDATION SET: 0.174323860392893
#
# AVG_LOSS_FUNCTION OF EPOCH 171 ON TRAINING SET: 0.15738940807202603
#
# AVG_LOSS_FUNCTION OF EPOCH 171 ON VALIDATION SET: 0.1746409216894279
#
# AVG_LOSS_FUNCTION OF EPOCH 172 ON TRAINING SET: 0.15727636280877844
#
# AVG_LOSS_FUNCTION OF EPOCH 172 ON VALIDATION SET: 0.17425277011723742
#
# AVG_LOSS_FUNCTION OF EPOCH 173 ON TRAINING SET: 0.15718128630524938
#
# AVG_LOSS_FUNCTION OF EPOCH 173 ON VALIDATION SET: 0.17457418883801676
#
# AVG_LOSS_FUNCTION OF EPOCH 174 ON TRAINING SET: 0.15707027733043055
#
# AVG_LOSS_FUNCTION OF EPOCH 174 ON VALIDATION SET: 0.17418776486776094
#
# AVG_LOSS_FUNCTION OF EPOCH 175 ON TRAINING SET: 0.15697689417710883
#
# AVG_LOSS_FUNCTION OF EPOCH 175 ON VALIDATION SET: 0.1745130191308759
#
# AVG_LOSS_FUNCTION OF EPOCH 176 ON TRAINING SET: 0.15686732977756795
#
# AVG_LOSS_FUNCTION OF EPOCH 176 ON VALIDATION SET: 0.1741259125334499
#
# AVG_LOSS_FUNCTION OF EPOCH 177 ON TRAINING SET: 0.15677584123184335
#
# AVG_LOSS_FUNCTION OF EPOCH 177 ON VALIDATION SET: 0.17445515067821726
#
# AVG_LOSS_FUNCTION OF EPOCH 178 ON TRAINING SET: 0.15667925546233377
#
# AVG_LOSS_FUNCTION OF EPOCH 178 ON VALIDATION SET: 0.17406644801606622
#
# AVG_LOSS_FUNCTION OF EPOCH 179 ON TRAINING SET: 0.15651871308289017
#
# AVG_LOSS_FUNCTION OF EPOCH 179 ON VALIDATION SET: 0.17441290991895445
# AVG_LOSS_FUNCTION OF EPOCH 180 ON TRAINING SET: 0.15647304056019623
#
# AVG_LOSS_FUNCTION OF EPOCH 180 ON VALIDATION SET: 0.17394007187729707
#
# AVG_LOSS_FUNCTION OF EPOCH 181 ON TRAINING SET: 0.15633805968480866
#
# AVG_LOSS_FUNCTION OF EPOCH 181 ON VALIDATION SET: 0.1743091798179572
#
# AVG_LOSS_FUNCTION OF EPOCH 182 ON TRAINING SET: 0.15629722380680974
#
# AVG_LOSS_FUNCTION OF EPOCH 182 ON VALIDATION SET: 0.17385682123863533
#
# AVG_LOSS_FUNCTION OF EPOCH 183 ON TRAINING SET: 0.15615146140592173
#
# AVG_LOSS_FUNCTION OF EPOCH 183 ON VALIDATION SET: 0.17424729926106888
#
# AVG_LOSS_FUNCTION OF EPOCH 184 ON TRAINING SET: 0.1560996782960467
#
# AVG_LOSS_FUNCTION OF EPOCH 184 ON VALIDATION SET: 0.17378939781788957
#
# AVG_LOSS_FUNCTION OF EPOCH 185 ON TRAINING SET: 0.15596638978120886
#
# AVG_LOSS_FUNCTION OF EPOCH 185 ON VALIDATION SET: 0.17418188224019315
#
# AVG_LOSS_FUNCTION OF EPOCH 186 ON TRAINING SET: 0.15591569286854537
#
# AVG_LOSS_FUNCTION OF EPOCH 186 ON VALIDATION SET: 0.1737111289971076
#
# AVG_LOSS_FUNCTION OF EPOCH 187 ON TRAINING SET: 0.15578717319640495
#
# AVG_LOSS_FUNCTION OF EPOCH 187 ON VALIDATION SET: 0.1741166758011129
#
# AVG_LOSS_FUNCTION OF EPOCH 188 ON TRAINING SET: 0.1556862300235616
#
# AVG_LOSS_FUNCTION OF EPOCH 188 ON VALIDATION SET: 0.17364543174547614
#
# AVG_LOSS_FUNCTION OF EPOCH 189 ON TRAINING SET: 0.15560557513357676
#
# AVG_LOSS_FUNCTION OF EPOCH 189 ON VALIDATION SET: 0.17399612058117767
#
# AVG_LOSS_FUNCTION OF EPOCH 190 ON TRAINING SET: 0.15551175798188452
#
# AVG_LOSS_FUNCTION OF EPOCH 190 ON VALIDATION SET: 0.17354241468231402
#
# AVG_LOSS_FUNCTION OF EPOCH 191 ON TRAINING SET: 0.1554340461290123
#
# AVG_LOSS_FUNCTION OF EPOCH 191 ON VALIDATION SET: 0.17390094968729422
#
# AVG_LOSS_FUNCTION OF EPOCH 192 ON TRAINING SET: 0.15534215898710804
#
# AVG_LOSS_FUNCTION OF EPOCH 192 ON VALIDATION SET: 0.17374994083342168
#
# AVG_LOSS_FUNCTION OF EPOCH 193 ON TRAINING SET: 0.15524605970431535
#
# AVG_LOSS_FUNCTION OF EPOCH 193 ON VALIDATION SET: 0.17332910328702228
#
# AVG_LOSS_FUNCTION OF EPOCH 194 ON TRAINING SET: 0.1551703529425115
#
# AVG_LOSS_FUNCTION OF EPOCH 194 ON VALIDATION SET: 0.1736975120223323
#
# AVG_LOSS_FUNCTION OF EPOCH 195 ON TRAINING SET: 0.155084105609399
#
# AVG_LOSS_FUNCTION OF EPOCH 195 ON VALIDATION SET: 0.17328091324688372
#
# AVG_LOSS_FUNCTION OF EPOCH 196 ON TRAINING SET: 0.15499608302064444
#
# AVG_LOSS_FUNCTION OF EPOCH 196 ON VALIDATION SET: 0.173683180662701
#
# AVG_LOSS_FUNCTION OF EPOCH 197 ON TRAINING SET: 0.15491195064182417
#
# AVG_LOSS_FUNCTION OF EPOCH 197 ON VALIDATION SET: 0.1735353929571006
#
# AVG_LOSS_FUNCTION OF EPOCH 198 ON TRAINING SET: 0.1548270179550722
#
# AVG_LOSS_FUNCTION OF EPOCH 198 ON VALIDATION SET: 0.17313496690775906
#
# AVG_LOSS_FUNCTION OF EPOCH 199 ON TRAINING SET: 0.1547373289067037
#
# AVG_LOSS_FUNCTION OF EPOCH 199 ON VALIDATION SET: 0.17354306816514162

# %%
HW3.predict()
# Out:
#        X0     X1  Y true  Y pred.   Cost  Prediction Correct?
# 0   0.683  0.796     0.0    0.002  0.002         0.0      Yes
# 1   0.689  0.394     1.0    0.897  0.108         1.0      Yes
# 2   0.053  0.621     1.0    0.788  0.239         1.0      Yes
# 3   0.918  0.753     0.0    0.001  0.001         0.0      Yes
# 4   0.369  0.075     0.0    0.010  0.010         0.0      Yes
# ..    ...    ...     ...      ...    ...         ...      ...
# 77  0.953  0.659     0.0    0.004  0.004         0.0      Yes
# 78  0.844  0.635     0.0    0.010  0.010         0.0      Yes
# 79  0.374  0.635     1.0    0.866  0.143         1.0      Yes
# 80  0.057  0.391     0.0    0.053  0.054         0.0      Yes
# 81  0.590  0.285     1.0    0.968  0.033         1.0      Yes
#
# [82 rows x 7 columns]
#
#  ACCURACY: 97.5609756097561 %
#
#  AVERAGE COST FUNCTION: 0.1855
#
#  ---------------
#
# CONFUSION MATRIX
#
#                Predicted Class= 1  Predicted Class= 0
# True Class= 1                  40                   1
# True Class= 0                   1                  40
# 0.975609756097561

# %% [markdown]
# ### Plots

# %%
Validation_Set = np.empty(HW3.epochs-1)
for i in range (1,HW3.epochs):
    Validation_Set[i-1] = HW3.loss_val_epochs[i]

# %%
Training_Set = np.empty(HW3.epochs-1)
for i in range (1,HW3.epochs):
    Training_Set[i-1] = HW3.loss_epochs[i]

# %%
epochs = np.arange(HW3.epochs-1)

# %%
plt.figure(figsize=(20,10))
plt.plot(epochs, Training_Set, color='Blue')
plt.yticks(np.arange(0,1.4,0.1))
plt.xticks(np.arange(0,210,10))
plt.title('Loss Function (Training Set)', fontsize=25)
plt.xlabel('Epoch #', fontsize=14)
plt.ylabel('Avg. Cross-Entropy', fontsize=14)
# Out:
# Text(0, 0.5, 'Avg. Cross-Entropy')

# %%
plt.figure(figsize=(20,10))
plt.plot(epochs, Validation_Set, color='Blue')
plt.yticks(np.arange(0,2.1,0.1))
plt.xticks(np.arange(0,210,10))
plt.title('Loss Function (Validation Set)', fontsize=25)
plt.xlabel('Epoch #', fontsize=14)
plt.ylabel('Avg. Cross-Entropy', fontsize=14)
# Out:
# Text(0, 0.5, 'Avg. Cross-Entropy')
